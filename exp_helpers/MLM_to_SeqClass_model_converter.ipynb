# %% [markdown]
# # Convert MaskedLM model to a SequenceClassification model

# %%
import torch
from transformers import AutoModelForMaskedLM, AutoModelForSequenceClassification
from transformers import AutoTokenizer

import os

# %%
local_model_base_dir = '../../local_models/'

# %%
MaskedLM_model_path = local_model_base_dir + 'bert-base-uncased_option1_with_bertram'
SeqClassification_model_path = local_model_base_dir + 'bert-base-uncased_option1_with_bertram_SC'

# %%
if os.path.exists(SeqClassification_model_path):
    err = f"Error! Directory {SeqClassification_model_path} already exists!"
    raise Exception(err)

# %% [markdown]
# ## Load as Masked LM and save as SequenceClassification model

# %%
print(f"Going to load the MaskedLM model from {MaskedLM_model_path} and convert it into a SequenceClassification \
model and save it at {SeqClassification_model_path}")
# Out:
# Going to load the MaskedLM model from ../../local_models/bert-base-uncased_option1_with_bertram and convert it into a SequenceClassification model and save it at ../../local_models/bert-base-uncased_option1_with_bertram_SC

# %%
# Load the models
model = AutoModelForSequenceClassification.from_pretrained(MaskedLM_model_path)
tokenizer = AutoTokenizer.from_pretrained(MaskedLM_model_path, use_fast=False, truncation=True)
# Out:
# Some weights of the model checkpoint at ../../local_models/bert-base-uncased_option1_with_bertram were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.LayerNorm.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ../../local_models/bert-base-uncased_option1_with_bertram and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Save the models
model.save_pretrained(SeqClassification_model_path)
tokenizer.save_pretrained(SeqClassification_model_path)
print(f"Saved the SequenceClassification model at {SeqClassification_model_path}")
# Out:
# Saved the SequenceClassification model at ../../local_models/bert-base-uncased_option1_with_bertram_SC

# %% [markdown]
# ## Test the Tokenizer & SequenceClassification model

# %%
tokenizer.get_added_vocab()
# Out:
# {'<BERTRAM:IDaboveboardID>': 30522,
#  '<BERTRAM:IDaboveparID>': 30523,
#  '<BERTRAM:IDacrosstheboardID>': 30524,
#  '<BERTRAM:IDaddfueltothefireID>': 30525,
#  '<BERTRAM:IDagainstthegrainID>': 30526,
#  '<BERTRAM:IDaheadofthecurveID>': 30527,
#  '<BERTRAM:IDaheadofthegameID>': 30528,
#  '<BERTRAM:IDallalongID>': 30529,
#  '<BERTRAM:IDallbetsareoffID>': 30530,
#  '<BERTRAM:IDalldressedupandnowheretogoID>': 30531,
#  '<BERTRAM:IDallhellbrokelooseID>': 30532,
#  '<BERTRAM:IDalloverbartheshoutingID>': 30533,
#  '<BERTRAM:IDalloverthemapID>': 30534,
#  '<BERTRAM:IDallovertheplaceID>': 30535,
#  '<BERTRAM:IDallovertheshopID>': 30536,
#  '<BERTRAM:IDallovertheshowID>': 30537,
#  '<BERTRAM:IDalltherageID>': 30538,
#  '<BERTRAM:IDallthingsbeingequalID>': 30539,
#  '<BERTRAM:IDallwetID>': 30540,
#  '<BERTRAM:IDalongaboutID>': 30541,
#  '<BERTRAM:IDandallthatjazzID>': 30542,
#  '<BERTRAM:IDandthensomeID>': 30543,
#  '<BERTRAM:IDanoldflameID>': 30544,
#  '<BERTRAM:IDarguethetossID>': 30545,
#  '<BERTRAM:IDarmedtotheteethID>': 30546,
#  '<BERTRAM:IDaroundtheclockID>': 30547,
#  '<BERTRAM:IDasaruleID>': 30548,
#  '<BERTRAM:IDasgoodasnewID>': 30549,
#  '<BERTRAM:IDaskforthemoonID>': 30550,
#  '<BERTRAM:IDasleepatthewheelID>': 30551,
#  '<BERTRAM:IDasluckwouldhaveitID>': 30552,
#  '<BERTRAM:IDasthecrowfliesID>': 30553,
#  '<BERTRAM:IDatacanterID>': 30554,
#  '<BERTRAM:IDatalooseendID>': 30555,
#  '<BERTRAM:IDatalossforwordsID>': 30556,
#  '<BERTRAM:IDatapinchID>': 30557,
#  '<BERTRAM:IDatastretchID>': 30558,
#  '<BERTRAM:IDatcrosspurposesID>': 30559,
#  '<BERTRAM:IDatdaggersdrawnID>': 30560,
#  '<BERTRAM:IDatloggerheadsID>': 30561,
#  '<BERTRAM:IDatseaID>': 30562,
#  '<BERTRAM:IDatsixesandsevensID>': 30563,
#  '<BERTRAM:IDatthecoalfaceID>': 30564,
#  '<BERTRAM:IDatthecrossroadsID>': 30565,
#  '<BERTRAM:IDatthedropofahatID>': 30566,
#  '<BERTRAM:IDattheendofthedayID>': 30567,
#  '<BERTRAM:IDatyourfingertipsID>': 30568,
#  '<BERTRAM:IDbacktosquareoneID>': 30569,
#  '<BERTRAM:IDbacktothedrawingboardID>': 30570,
#  '<BERTRAM:IDbagandbaggageID>': 30571,
#  '<BERTRAM:IDbananarepublicID>': 30572,
#  '<BERTRAM:IDbangforthebuckID>': 30573,
#  '<BERTRAM:IDbangtorightsID>': 30574,
#  '<BERTRAM:IDbarnoneID>': 30575,
#  '<BERTRAM:IDbasketcaseID>': 30576,
#  '<BERTRAM:IDbeallearsID>': 30577,
#  '<BERTRAM:IDbearfruitID>': 30578,
#  '<BERTRAM:IDbearinmindID>': 30579,
#  '<BERTRAM:IDbeataboutthebushID>': 30580,
#  '<BERTRAM:IDbeattheclockID>': 30581,
#  '<BERTRAM:IDbeatthemeatID>': 30582,
#  '<BERTRAM:IDbeattherapID>': 30583,
#  '<BERTRAM:IDbedroomeyesID>': 30584,
#  '<BERTRAM:IDbegthequestionID>': 30585,
#  '<BERTRAM:IDbehindbarsID>': 30586,
#  '<BERTRAM:IDbehindcloseddoorsID>': 30587,
#  '<BERTRAM:IDbehindthecurveID>': 30588,
#  '<BERTRAM:IDbehindtheeightballID>': 30589,
#  '<BERTRAM:IDbehindthescenesID>': 30590,
#  '<BERTRAM:IDbellthecatID>': 30591,
#  '<BERTRAM:IDbelowparID>': 30592,
#  '<BERTRAM:IDbelowthebeltID>': 30593,
#  '<BERTRAM:IDbeltandbracesID>': 30594,
#  '<BERTRAM:IDbemyguestID>': 30595,
#  '<BERTRAM:IDbesideyourselfID>': 30596,
#  '<BERTRAM:IDbetterthedevilyouknowID>': 30597,
#  '<BERTRAM:IDbetweenarockandahardplaceID>': 30598,
#  '<BERTRAM:IDbetweenthedevilandthedeepblueseaID>': 30599,
#  '<BERTRAM:IDbetwixtandbetweenID>': 30600,
#  '<BERTRAM:IDbeyondthepaleID>': 30601,
#  '<BERTRAM:IDbighitterID>': 30602,
#  '<BERTRAM:IDbirdsofafeatherID>': 30603,
#  '<BERTRAM:IDbiteoffmorethanyoucanchewID>': 30604,
#  '<BERTRAM:IDbitethebulletID>': 30605,
#  '<BERTRAM:IDbitethedustID>': 30606,
#  '<BERTRAM:IDbiteyourlipID>': 30607,
#  '<BERTRAM:IDbiteyourtongueID>': 30608,
#  '<BERTRAM:IDblackandblueID>': 30609,
#  '<BERTRAM:IDblazeatrailID>': 30610,
#  '<BERTRAM:IDbleedingheartID>': 30611,
#  '<BERTRAM:IDbloodandgutsID>': 30612,
#  '<BERTRAM:IDbloodandthunderID>': 30613,
#  '<BERTRAM:IDbloodisthickerthanwaterID>': 30614,
#  '<BERTRAM:IDblowafuseID>': 30615,
#  '<BERTRAM:IDblowhotandcoldID>': 30616,
#  '<BERTRAM:IDblowoffsteamID>': 30617,
#  '<BERTRAM:IDblowthelidoffID>': 30618,
#  '<BERTRAM:IDbootsandallID>': 30619,
#  '<BERTRAM:IDbornandbredID>': 30620,
#  '<BERTRAM:IDbowandscrapeID>': 30621,
#  '<BERTRAM:IDboxcleverID>': 30622,
#  '<BERTRAM:IDboysinblueID>': 30623,
#  '<BERTRAM:IDboyswillbeboysID>': 30624,
#  '<BERTRAM:IDbrassmonkeyID>': 30625,
#  '<BERTRAM:IDbrassneckID>': 30626,
#  '<BERTRAM:IDbreadandcircusesID>': 30627,
#  '<BERTRAM:IDbreakcoverID>': 30628,
#  '<BERTRAM:IDbreakevenID>': 30629,
#  '<BERTRAM:IDbreaknewgroundID>': 30630,
#  '<BERTRAM:IDbreakranksID>': 30631,
#  '<BERTRAM:IDbreakthebackofID>': 30632,
#  '<BERTRAM:IDbreakthebankID>': 30633,
#  '<BERTRAM:IDbreaktheiceID>': 30634,
#  '<BERTRAM:IDbrightyoungthingID>': 30635,
#  '<BERTRAM:IDbringhomethebaconID>': 30636,
#  '<BERTRAM:IDbringthehousedownID>': 30637,
#  '<BERTRAM:IDbringuptherearID>': 30638,
#  '<BERTRAM:IDbrowniepointID>': 30639,
#  '<BERTRAM:IDbuggerallID>': 30640,
#  '<BERTRAM:IDbumsteerID>': 30641,
#  '<BERTRAM:IDbundleofjoyID>': 30642,
#  '<BERTRAM:IDburnrubberID>': 30643,
#  '<BERTRAM:IDburnthecandleatbothendsID>': 30644,
#  '<BERTRAM:IDburnthemidnightoilID>': 30645,
#  '<BERTRAM:IDbushtelegraphID>': 30646,
#  '<BERTRAM:IDbuythefarmID>': 30647,
#  '<BERTRAM:IDbuytimeID>': 30648,
#  '<BERTRAM:IDbyalongchalkID>': 30649,
#  '<BERTRAM:IDbyalongshotID>': 30650,
#  '<BERTRAM:IDbyandlargeID>': 30651,
#  '<BERTRAM:IDbydintofID>': 30652,
#  '<BERTRAM:IDbyheartID>': 30653,
#  '<BERTRAM:IDbyhookorbycrookID>': 30654,
#  '<BERTRAM:IDbyleapsandboundsID>': 30655,
#  '<BERTRAM:IDbynostretchoftheimaginationID>': 30656,
#  '<BERTRAM:IDbythebackdoorID>': 30657,
#  '<BERTRAM:IDbythebookID>': 30658,
#  '<BERTRAM:IDbythebyID>': 30659,
#  '<BERTRAM:IDbythesametokenID>': 30660,
#  '<BERTRAM:IDbytheseatofyourpantsID>': 30661,
#  '<BERTRAM:IDcallaspadeaspadeID>': 30662,
#  '<BERTRAM:IDcallitadayID>': 30663,
#  '<BERTRAM:IDcallitquitsID>': 30664,
#  '<BERTRAM:IDcalltheshotsID>': 30665,
#  '<BERTRAM:IDcapinhandID>': 30666,
#  '<BERTRAM:IDcarrotandstickID>': 30667,
#  '<BERTRAM:IDcastthefirststoneID>': 30668,
#  '<BERTRAM:IDcastyourmindbackID>': 30669,
#  '<BERTRAM:IDcatchacoldID>': 30670,
#  '<BERTRAM:IDcatchfireID>': 30671,
#  '<BERTRAM:IDcatchthesunID>': 30672,
#  '<BERTRAM:IDchampatthebitID>': 30673,
#  '<BERTRAM:IDchangeyourtuneID>': 30674,
#  '<BERTRAM:IDchapterandverseID>': 30675,
#  '<BERTRAM:IDcheekbyjowlID>': 30676,
#  '<BERTRAM:IDchewthecudID>': 30677,
#  '<BERTRAM:IDchewthefatID>': 30678,
#  '<BERTRAM:IDchickenfeedID>': 30679,
#  '<BERTRAM:IDchickenscomehometoroostID>': 30680,
#  '<BERTRAM:IDchopandchangeID>': 30681,
#  '<BERTRAM:IDcleanasawhistleID>': 30682,
#  '<BERTRAM:IDcleanhouseID>': 30683,
#  '<BERTRAM:IDclearasmudID>': 30684,
#  '<BERTRAM:IDclearthedecksID>': 30685,
#  '<BERTRAM:IDclosebutnocigarID>': 30686,
#  '<BERTRAM:IDclosecallID>': 30687,
#  '<BERTRAM:IDcloseranksID>': 30688,
#  '<BERTRAM:IDcloseshaveID>': 30689,
#  '<BERTRAM:IDclosetohomeID>': 30690,
#  '<BERTRAM:IDclutchatstrawsID>': 30691,
#  '<BERTRAM:IDcockofthewalkID>': 30692,
#  '<BERTRAM:IDcoginthemachineID>': 30693,
#  '<BERTRAM:IDcoldfeetID>': 30694,
#  '<BERTRAM:IDcollectdustID>': 30695,
#  '<BERTRAM:IDcomeacropperID>': 30696,
#  '<BERTRAM:IDcomecleanID>': 30697,
#  '<BERTRAM:IDcomedownthepikeID>': 30698,
#  '<BERTRAM:IDcomefullcircleID>': 30699,
#  '<BERTRAM:IDcomehellorhighwaterID>': 30700,
#  '<BERTRAM:IDcomeinfromthecoldID>': 30701,
#  '<BERTRAM:IDcomeofageID>': 30702,
#  '<BERTRAM:IDcomeoutinthewashID>': 30703,
#  '<BERTRAM:IDcomeoutofyourshellID>': 30704,
#  '<BERTRAM:IDcometoaheadID>': 30705,
#  '<BERTRAM:IDcometogriefID>': 30706,
#  '<BERTRAM:IDcometogripswithID>': 30707,
#  '<BERTRAM:IDcometomindID>': 30708,
#  '<BERTRAM:IDcometotermswithID>': 30709,
#  '<BERTRAM:IDcometothinkofitID>': 30710,
#  '<BERTRAM:IDcomeunstuckID>': 30711,
#  '<BERTRAM:IDcomeuptrumpsID>': 30712,
#  '<BERTRAM:IDconfirmedbachelorID>': 30713,
#  '<BERTRAM:IDcookthebooksID>': 30714,
#  '<BERTRAM:IDcosttheearthID>': 30715,
#  '<BERTRAM:IDcouchpotatoID>': 30716,
#  '<BERTRAM:IDcountsheepID>': 30717,
#  '<BERTRAM:IDcountyourblessingsID>': 30718,
#  '<BERTRAM:IDcrashandburnID>': 30719,
#  '<BERTRAM:IDcrossmyheartID>': 30720,
#  '<BERTRAM:IDcrossswordsID>': 30721,
#  '<BERTRAM:IDcrosstherubiconID>': 30722,
#  '<BERTRAM:IDcryfoulID>': 30723,
#  '<BERTRAM:IDcrystalclearID>': 30724,
#  '<BERTRAM:IDcrywolfID>': 30725,
#  '<BERTRAM:IDcuriositykilledthecatID>': 30726,
#  '<BERTRAM:IDcutanddriedID>': 30727,
#  '<BERTRAM:IDcutandthrustID>': 30728,
#  '<BERTRAM:IDcutarugID>': 30729,
#  '<BERTRAM:IDcutbothwaysID>': 30730,
#  '<BERTRAM:IDcutcornersID>': 30731,
#  '<BERTRAM:IDcutfromthesameclothID>': 30732,
#  '<BERTRAM:IDcutitfineID>': 30733,
#  '<BERTRAM:IDcutlooseID>': 30734,
#  '<BERTRAM:IDcutnoiceID>': 30735,
#  '<BERTRAM:IDcutthecrapID>': 30736,
#  '<BERTRAM:IDcutthemustardID>': 30737,
#  '<BERTRAM:IDcutyourlossesID>': 30738,
#  '<BERTRAM:IDdeadandburiedID>': 30739,
#  '<BERTRAM:IDdeadasadodoID>': 30740,
#  '<BERTRAM:IDdeadasadoornailID>': 30741,
#  '<BERTRAM:IDdeadinthewaterID>': 30742,
#  '<BERTRAM:IDdeadmeatID>': 30743,
#  '<BERTRAM:IDdeadtotheworldID>': 30744,
#  '<BERTRAM:IDdeadwoodID>': 30745,
#  '<BERTRAM:IDdicewithdeathID>': 30746,
#  '<BERTRAM:IDdieonthevineID>': 30747,
#  '<BERTRAM:IDdigdeepID>': 30748,
#  '<BERTRAM:IDdigupdirtID>': 30749,
#  '<BERTRAM:IDdiscretionisthebetterpartofvalourID>': 30750,
#  '<BERTRAM:IDdishthedirtID>': 30751,
#  '<BERTRAM:IDdoanumberonID>': 30752,
#  '<BERTRAM:IDdoarunnerID>': 30753,
#  '<BERTRAM:IDdogeatdogID>': 30754,
#  '<BERTRAM:IDdoginthemangerID>': 30755,
#  '<BERTRAM:IDdogtiredID>': 30756,
#  '<BERTRAM:IDdomeafavourID>': 30757,
#  '<BERTRAM:IDdonkeyworkID>': 30758,
#  '<BERTRAM:IDdoomandgloomID>': 30759,
#  '<BERTRAM:IDdothehonoursID>': 30760,
#  '<BERTRAM:IDdotherightthingID>': 30761,
#  '<BERTRAM:IDdothetrickID>': 30762,
#  '<BERTRAM:IDdownandoutID>': 30763,
#  '<BERTRAM:IDdowninthedumpsID>': 30764,
#  '<BERTRAM:IDdownthedrainID>': 30765,
#  '<BERTRAM:IDdownthehatchID>': 30766,
#  '<BERTRAM:IDdowntheroadID>': 30767,
#  '<BERTRAM:IDdownthetubesID>': 30768,
#  '<BERTRAM:IDdowntothewireID>': 30769,
#  '<BERTRAM:IDdragyourfeetID>': 30770,
#  '<BERTRAM:IDdrawablankID>': 30771,
#  '<BERTRAM:IDdrawalineinthesandID>': 30772,
#  '<BERTRAM:IDdrawstumpsID>': 30773,
#  '<BERTRAM:IDdrawtheshortstrawID>': 30774,
#  '<BERTRAM:IDdressedtokillID>': 30775,
#  '<BERTRAM:IDdressedtotheninesID>': 30776,
#  '<BERTRAM:IDdropahintID>': 30777,
#  '<BERTRAM:IDdroplikefliesID>': 30778,
#  '<BERTRAM:IDdroptheballID>': 30779,
#  '<BERTRAM:IDdrownyoursorrowsID>': 30780,
#  '<BERTRAM:IDducksoupID>': 30781,
#  '<BERTRAM:IDdukeitoutID>': 30782,
#  '<BERTRAM:IDdutchcourageID>': 30783,
#  '<BERTRAM:IDdyedinthewoolID>': 30784,
#  '<BERTRAM:IDeasiersaidthandoneID>': 30785,
#  '<BERTRAM:IDeathumblepieID>': 30786,
#  '<BERTRAM:IDeatlikeahorseID>': 30787,
#  '<BERTRAM:IDeatyourwordsID>': 30788,
#  '<BERTRAM:IDeconomicalwiththetruthID>': 30789,
#  '<BERTRAM:IDerronthesideofID>': 30790,
#  '<BERTRAM:IDeverythingbutthekitchensinkID>': 30791,
#  '<BERTRAM:IDfacethemusicID>': 30792,
#  '<BERTRAM:IDfacetofaceID>': 30793,
#  '<BERTRAM:IDfairandsquareID>': 30794,
#  '<BERTRAM:IDfairgameID>': 30795,
#  '<BERTRAM:IDfallbythewaysideID>': 30796,
#  '<BERTRAM:IDfallfromgraceID>': 30797,
#  '<BERTRAM:IDfallinlineID>': 30798,
#  '<BERTRAM:IDfallintoplaceID>': 30799,
#  '<BERTRAM:IDfallondeafearsID>': 30800,
#  '<BERTRAM:IDfallshortID>': 30801,
#  '<BERTRAM:IDfarandawayID>': 30802,
#  '<BERTRAM:IDfastandfuriousID>': 30803,
#  '<BERTRAM:IDfeastorfamineID>': 30804,
#  '<BERTRAM:IDfeelthepinchID>': 30805,
#  '<BERTRAM:IDfewandfarbetweenID>': 30806,
#  '<BERTRAM:IDfightfirewithfireID>': 30807,
#  '<BERTRAM:IDfighttoothandnailID>': 30808,
#  '<BERTRAM:IDfillthebillID>': 30809,
#  '<BERTRAM:IDfindyourfeetID>': 30810,
#  '<BERTRAM:IDfirstamongequalsID>': 30811,
#  '<BERTRAM:IDfirstoffID>': 30812,
#  '<BERTRAM:IDfirstupID>': 30813,
#  '<BERTRAM:IDfishintroubledwatersID>': 30814,
#  '<BERTRAM:IDfitasafiddleID>': 30815,
#  '<BERTRAM:IDfitlikeagloveID>': 30816,
#  '<BERTRAM:IDfitthebillID>': 30817,
#  '<BERTRAM:IDfittobetiedID>': 30818,
#  '<BERTRAM:IDflashinthepanID>': 30819,
#  '<BERTRAM:IDflatasapancakeID>': 30820,
#  '<BERTRAM:IDflyinthefaceofID>': 30821,
#  '<BERTRAM:IDfoamatthemouthID>': 30822,
#  '<BERTRAM:IDfollowsuitID>': 30823,
#  '<BERTRAM:IDfollowyournoseID>': 30824,
#  '<BERTRAM:IDforafricaID>': 30825,
#  '<BERTRAM:IDforasongID>': 30826,
#  '<BERTRAM:IDforbiddenfruitID>': 30827,
#  '<BERTRAM:IDforgoodmeasureID>': 30828,
#  '<BERTRAM:IDforkeepsID>': 30829,
#  '<BERTRAM:IDformymoneyID>': 30830,
#  '<BERTRAM:IDforthehellofitID>': 30831,
#  '<BERTRAM:IDforthetimebeingID>': 30832,
#  '<BERTRAM:IDfreereinID>': 30833,
#  '<BERTRAM:IDfriendsinhighplacesID>': 30834,
#  '<BERTRAM:IDfromatozID>': 30835,
#  '<BERTRAM:IDfrompillartopostID>': 30836,
#  '<BERTRAM:IDfromragstorichesID>': 30837,
#  '<BERTRAM:IDfromscratchID>': 30838,
#  '<BERTRAM:IDfromthecradletothegraveID>': 30839,
#  '<BERTRAM:IDfromthewordgoID>': 30840,
#  '<BERTRAM:IDfullmarksID>': 30841,
#  '<BERTRAM:IDfullofbeansID>': 30842,
#  '<BERTRAM:IDfullspeedaheadID>': 30843,
#  '<BERTRAM:IDfulltiltID>': 30844,
#  '<BERTRAM:IDfullwhackID>': 30845,
#  '<BERTRAM:IDfunandgamesID>': 30846,
#  '<BERTRAM:IDgameonID>': 30847,
#  '<BERTRAM:IDgatherdustID>': 30848,
#  '<BERTRAM:IDgetagripID>': 30849,
#  '<BERTRAM:IDgetahandleonID>': 30850,
#  '<BERTRAM:IDgetalifeID>': 30851,
#  '<BERTRAM:IDgetamoveonID>': 30852,
#  '<BERTRAM:IDgetariseoutofID>': 30853,
#  '<BERTRAM:IDgetawaywithmurderID>': 30854,
#  '<BERTRAM:IDgetdowntobrasstacksID>': 30855,
#  '<BERTRAM:IDgetinonthegroundfloorID>': 30856,
#  '<BERTRAM:IDgetitupID>': 30857,
#  '<BERTRAM:IDgetlostID>': 30858,
#  '<BERTRAM:IDgetoffthegroundID>': 30859,
#  '<BERTRAM:IDgetonlikeahouseonfireID>': 30860,
#  '<BERTRAM:IDgetstuckinID>': 30861,
#  '<BERTRAM:IDgetstuckintoID>': 30862,
#  '<BERTRAM:IDgetthebetterofID>': 30863,
#  '<BERTRAM:IDgetthebootID>': 30864,
#  '<BERTRAM:IDgetthenodID>': 30865,
#  '<BERTRAM:IDgetthepictureID>': 30866,
#  '<BERTRAM:IDgettheshowontheroadID>': 30867,
#  '<BERTRAM:IDgettogripswithID>': 30868,
#  '<BERTRAM:IDgettothebottomofID>': 30869,
#  '<BERTRAM:IDgetwindofID>': 30870,
#  '<BERTRAM:IDgetyourfeetwetID>': 30871,
#  '<BERTRAM:IDgetyourskatesonID>': 30872,
#  '<BERTRAM:IDgetyourteethintoID>': 30873,
#  '<BERTRAM:IDgiveandtakeID>': 30874,
#  '<BERTRAM:IDgiveheadID>': 30875,
#  '<BERTRAM:IDgiveitawhirlID>': 30876,
#  '<BERTRAM:IDgiveuptheghostID>': 30877,
#  '<BERTRAM:IDgoallthewayID>': 30878,
#  '<BERTRAM:IDgoballisticID>': 30879,
#  '<BERTRAM:IDgobananasID>': 30880,
#  '<BERTRAM:IDgobeggingID>': 30881,
#  '<BERTRAM:IDgobytheboardID>': 30882,
#  '<BERTRAM:IDgodownhillID>': 30883,
#  '<BERTRAM:IDgodutchID>': 30884,
#  '<BERTRAM:IDgoforbrokeID>': 30885,
#  '<BERTRAM:IDgoforthejugularID>': 30886,
#  '<BERTRAM:IDgofromstrengthtostrengthID>': 30887,
#  '<BERTRAM:IDgohalvesID>': 30888,
#  '<BERTRAM:IDgohandinhandID>': 30889,
#  '<BERTRAM:IDgoitaloneID>': 30890,
#  '<BERTRAM:IDgonativeID>': 30891,
#  '<BERTRAM:IDgoodofficesID>': 30892,
#  '<BERTRAM:IDgoodriddanceID>': 30893,
#  '<BERTRAM:IDgoodsamaritanID>': 30894,
#  '<BERTRAM:IDgooverboardID>': 30895,
#  '<BERTRAM:IDgoplacesID>': 30896,
#  '<BERTRAM:IDgopublicID>': 30897,
#  '<BERTRAM:IDgoroundincirclesID>': 30898,
#  '<BERTRAM:IDgospareID>': 30899,
#  '<BERTRAM:IDgostraightID>': 30900,
#  '<BERTRAM:IDgothedistanceID>': 30901,
#  '<BERTRAM:IDgotheextramileID>': 30902,
#  '<BERTRAM:IDgothewholehogID>': 30903,
#  '<BERTRAM:IDgothroughthemotionsID>': 30904,
#  '<BERTRAM:IDgotogroundID>': 30905,
#  '<BERTRAM:IDgotoseedID>': 30906,
#  '<BERTRAM:IDgotothedogsID>': 30907,
#  '<BERTRAM:IDgotothematID>': 30908,
#  '<BERTRAM:IDgotothewallID>': 30909,
#  '<BERTRAM:IDgototownID>': 30910,
#  '<BERTRAM:IDgotoyourheadID>': 30911,
#  '<BERTRAM:IDgounderthehammerID>': 30912,
#  '<BERTRAM:IDgoupinsmokeID>': 30913,
#  '<BERTRAM:IDgowestID>': 30914,
#  '<BERTRAM:IDgowithoutsayingID>': 30915,
#  '<BERTRAM:IDgraspthenettleID>': 30916,
#  '<BERTRAM:IDgreenlightID>': 30917,
#  '<BERTRAM:IDgrinandbearitID>': 30918,
#  '<BERTRAM:IDgrindtoahaltID>': 30919,
#  '<BERTRAM:IDgristtothemillID>': 30920,
#  '<BERTRAM:IDhackitID>': 30921,
#  '<BERTRAM:IDhairofthedogID>': 30922,
#  '<BERTRAM:IDhammerandtongsID>': 30923,
#  '<BERTRAM:IDhandingloveID>': 30924,
#  '<BERTRAM:IDhandsdownID>': 30925,
#  '<BERTRAM:IDhandtomouthID>': 30926,
#  '<BERTRAM:IDhangbyathreadID>': 30927,
#  '<BERTRAM:IDhangfireID>': 30928,
#  '<BERTRAM:IDhangtoughID>': 30929,
#  '<BERTRAM:IDhardasnailsID>': 30930,
#  '<BERTRAM:IDhardcheeseID>': 30931,
#  '<BERTRAM:IDhaveaballID>': 30932,
#  '<BERTRAM:IDhaveabashID>': 30933,
#  '<BERTRAM:IDhaveabunintheovenID>': 30934,
#  '<BERTRAM:IDhaveacowID>': 30935,
#  '<BERTRAM:IDhaveafewID>': 30936,
#  '<BERTRAM:IDhaveafootinbothcampsID>': 30937,
#  '<BERTRAM:IDhaveaheartID>': 30938,
#  '<BERTRAM:IDhaveamountaintoclimbID>': 30939,
#  '<BERTRAM:IDhaveaneyeforID>': 30940,
#  '<BERTRAM:IDhavebeenaroundID>': 30941,
#  '<BERTRAM:IDhaveitbothwaysID>': 30942,
#  '<BERTRAM:IDhaveiteasyID>': 30943,
#  '<BERTRAM:IDhavenotruckwithID>': 30944,
#  '<BERTRAM:IDhavethelastlaughID>': 30945,
#  '<BERTRAM:IDhavewordsID>': 30946,
#  '<BERTRAM:IDhaveyourworkcutoutID>': 30947,
#  '<BERTRAM:IDheadforthehillsID>': 30948,
#  '<BERTRAM:IDheadoverheelsID>': 30949,
#  '<BERTRAM:IDheadsouthID>': 30950,
#  '<BERTRAM:IDheadswillrollID>': 30951,
#  '<BERTRAM:IDheartandsoulID>': 30952,
#  '<BERTRAM:IDhearthingsID>': 30953,
#  '<BERTRAM:IDheartofgoldID>': 30954,
#  '<BERTRAM:IDhearttoheartID>': 30955,
#  '<BERTRAM:IDhighanddryID>': 30956,
#  '<BERTRAM:IDhighandlowID>': 30957,
#  '<BERTRAM:IDhighasakiteID>': 30958,
#  '<BERTRAM:IDhitandmissID>': 30959,
#  '<BERTRAM:IDhitanerveID>': 30960,
#  '<BERTRAM:IDhithomeID>': 30961,
#  '<BERTRAM:IDhitthebottleID>': 30962,
#  '<BERTRAM:IDhittheceilingID>': 30963,
#  '<BERTRAM:IDhitthegroundrunningID>': 30964,
#  '<BERTRAM:IDhitthehayID>': 30965,
#  '<BERTRAM:IDhittheheadlinesID>': 30966,
#  '<BERTRAM:IDhitthejackpotID>': 30967,
#  '<BERTRAM:IDhitthemarkID>': 30968,
#  '<BERTRAM:IDhitthenailontheheadID>': 30969,
#  '<BERTRAM:IDhittherightnoteID>': 30970,
#  '<BERTRAM:IDhittheroadID>': 30971,
#  '<BERTRAM:IDhitthesackID>': 30972,
#  '<BERTRAM:IDhittheskidsID>': 30973,
#  '<BERTRAM:IDholdalltheacesID>': 30974,
#  '<BERTRAM:IDholdcourtID>': 30975,
#  '<BERTRAM:IDholdthefortID>': 30976,
#  '<BERTRAM:IDholdthelineID>': 30977,
#  '<BERTRAM:IDholdthepursestringsID>': 30978,
#  '<BERTRAM:IDholdtheringID>': 30979,
#  '<BERTRAM:IDholdwaterID>': 30980,
#  '<BERTRAM:IDholdyourhorsesID>': 30981,
#  '<BERTRAM:IDholdyourownID>': 30982,
#  '<BERTRAM:IDholdyourtongueID>': 30983,
#  '<BERTRAM:IDhomeanddryID>': 30984,
#  '<BERTRAM:IDhopeagainsthopeID>': 30985,
#  '<BERTRAM:IDhotairID>': 30986,
#  '<BERTRAM:IDhotandbotheredID>': 30987,
#  '<BERTRAM:IDhottotrotID>': 30988,
#  '<BERTRAM:IDhotunderthecollarID>': 30989,
#  '<BERTRAM:IDinafogID>': 30990,
#  '<BERTRAM:IDinanutshellID>': 30991,
#  '<BERTRAM:IDinarutID>': 30992,
#  '<BERTRAM:IDinbedwithID>': 30993,
#  '<BERTRAM:IDinblackandwhiteID>': 30994,
#  '<BERTRAM:IDinbroaddaylightID>': 30995,
#  '<BERTRAM:IDinbusinessID>': 30996,
#  '<BERTRAM:IDincahootsID>': 30997,
#  '<BERTRAM:IDincoldbloodID>': 30998,
#  '<BERTRAM:IDindiansummerID>': 30999,
#  '<BERTRAM:IDindutchID>': 31000,
#  '<BERTRAM:IDinfullswingID>': 31001,
#  '<BERTRAM:IDinhighdudgeonID>': 31002,
#  '<BERTRAM:IDinhotwaterID>': 31003,
#  '<BERTRAM:IDinlightofID>': 31004,
#  '<BERTRAM:IDinmybookID>': 31005,
#  '<BERTRAM:IDinnouncertaintermsID>': 31006,
#  '<BERTRAM:IDinoneearandouttheotherID>': 31007,
#  '<BERTRAM:IDinspadesID>': 31008,
#  '<BERTRAM:IDinstitchesID>': 31009,
#  '<BERTRAM:IDintandemID>': 31010,
#  '<BERTRAM:IDinthebagID>': 31011,
#  '<BERTRAM:IDintheballparkID>': 31012,
#  '<BERTRAM:IDintheblackID>': 31013,
#  '<BERTRAM:IDintheblinkofaneyeID>': 31014,
#  '<BERTRAM:IDinthebuffID>': 31015,
#  '<BERTRAM:IDinthecanID>': 31016,
#  '<BERTRAM:IDintheclearID>': 31017,
#  '<BERTRAM:IDintheclubID>': 31018,
#  '<BERTRAM:IDinthedockID>': 31019,
#  '<BERTRAM:IDinthefinalanalysisID>': 31020,
#  '<BERTRAM:IDinthefleshID>': 31021,
#  '<BERTRAM:IDintheholeID>': 31022,
#  '<BERTRAM:IDinthelongrunID>': 31023,
#  '<BERTRAM:IDinthelongtermID>': 31024,
#  '<BERTRAM:IDintheloopID>': 31025,
#  '<BERTRAM:IDinthenickoftimeID>': 31026,
#  '<BERTRAM:IDintheoffingID>': 31027,
#  '<BERTRAM:IDinthepinkID>': 31028,
#  '<BERTRAM:IDinthepipelineID>': 31029,
#  '<BERTRAM:IDintherawID>': 31030,
#  '<BERTRAM:IDintheredID>': 31031,
#  '<BERTRAM:IDintherunningID>': 31032,
#  '<BERTRAM:IDinthesaddleID>': 31033,
#  '<BERTRAM:IDinthesamebreathID>': 31034,
#  '<BERTRAM:IDintheshortrunID>': 31035,
#  '<BERTRAM:IDinthesoupID>': 31036,
#  '<BERTRAM:IDinthesticksID>': 31037,
#  '<BERTRAM:IDintheworksID>': 31038,
#  '<BERTRAM:IDinthisdayandageID>': 31039,
#  '<BERTRAM:IDinyourbloodID>': 31040,
#  '<BERTRAM:IDinyourdreamsID>': 31041,
#  '<BERTRAM:IDinyourelementID>': 31042,
#  '<BERTRAM:IDinyourfaceID>': 31043,
#  '<BERTRAM:IDinyoursightsID>': 31044,
#  '<BERTRAM:IDittakestwototangoID>': 31045,
#  '<BERTRAM:IDjackofalltradesID>': 31046,
#  '<BERTRAM:IDjamtomorrowID>': 31047,
#  '<BERTRAM:IDjekyllandhydeID>': 31048,
#  '<BERTRAM:IDjobsfortheboysID>': 31049,
#  '<BERTRAM:IDjockeyforpositionID>': 31050,
#  '<BERTRAM:IDjoinedatthehipID>': 31051,
#  '<BERTRAM:IDjointheclubID>': 31052,
#  '<BERTRAM:IDjumponthebandwagonID>': 31053,
#  '<BERTRAM:IDjumpshipID>': 31054,
#  '<BERTRAM:IDjumpthegunID>': 31055,
#  '<BERTRAM:IDjumpthequeueID>': 31056,
#  '<BERTRAM:IDjumpthetrackID>': 31057,
#  '<BERTRAM:IDjumpthroughhoopsID>': 31058,
#  '<BERTRAM:IDjumptoconclusionsID>': 31059,
#  '<BERTRAM:IDkeenasmustardID>': 31060,
#  '<BERTRAM:IDkeepalidonID>': 31061,
#  '<BERTRAM:IDkeepalowprofileID>': 31062,
#  '<BERTRAM:IDkeepastraightfaceID>': 31063,
#  '<BERTRAM:IDkeepmumID>': 31064,
#  '<BERTRAM:IDkeepontruckingID>': 31065,
#  '<BERTRAM:IDkeeptabsonID>': 31066,
#  '<BERTRAM:IDkeepthepeaceID>': 31067,
#  '<BERTRAM:IDkeepthewolffromthedoorID>': 31068,
#  '<BERTRAM:IDkeepupappearancesID>': 31069,
#  '<BERTRAM:IDkeepupwiththejonesesID>': 31070,
#  '<BERTRAM:IDkeepyourchinupID>': 31071,
#  '<BERTRAM:IDkeepyoureyespeeledID>': 31072,
#  '<BERTRAM:IDkeepyourfingerscrossedID>': 31073,
#  '<BERTRAM:IDkeepyourheadID>': 31074,
#  '<BERTRAM:IDkickagainstthepricksID>': 31075,
#  '<BERTRAM:IDkickassID>': 31076,
#  '<BERTRAM:IDkickthebucketID>': 31077,
#  '<BERTRAM:IDkickthehabitID>': 31078,
#  '<BERTRAM:IDkickupafussID>': 31079,
#  '<BERTRAM:IDkickupastinkID>': 31080,
#  '<BERTRAM:IDkickupyourheelsID>': 31081,
#  '<BERTRAM:IDkilltwobirdswithonestoneID>': 31082,
#  '<BERTRAM:IDkingofbeastsID>': 31083,
#  '<BERTRAM:IDkissandmakeupID>': 31084,
#  '<BERTRAM:IDkissandtellID>': 31085,
#  '<BERTRAM:IDkissassID>': 31086,
#  '<BERTRAM:IDkissofdeathID>': 31087,
#  '<BERTRAM:IDkissoflifeID>': 31088,
#  '<BERTRAM:IDkithandkinID>': 31089,
#  '<BERTRAM:IDknockitoffID>': 31090,
#  '<BERTRAM:IDknownoboundsID>': 31091,
#  '<BERTRAM:IDknowtheropesID>': 31092,
#  '<BERTRAM:IDknowthescoreID>': 31093,
#  '<BERTRAM:IDlameduckID>': 31094,
#  '<BERTRAM:IDlandofnodID>': 31095,
#  '<BERTRAM:IDlargerthanlifeID>': 31096,
#  '<BERTRAM:IDlasthurrahID>': 31097,
#  '<BERTRAM:IDlaughallthewaytothebankID>': 31098,
#  '<BERTRAM:IDlaughingstockID>': 31099,
#  '<BERTRAM:IDlayafingeronID>': 31100,
#  '<BERTRAM:IDlayaneggID>': 31101,
#  '<BERTRAM:IDlaydownthelawID>': 31102,
#  '<BERTRAM:IDlayeyesonID>': 31103,
#  '<BERTRAM:IDleavenostoneunturnedID>': 31104,
#  '<BERTRAM:IDleftandrightID>': 31105,
#  '<BERTRAM:IDlendahandID>': 31106,
#  '<BERTRAM:IDlendanearID>': 31107,
#  '<BERTRAM:IDletbygonesbebygonesID>': 31108,
#  '<BERTRAM:IDletsleepingdogslieID>': 31109,
#  '<BERTRAM:IDletthecatoutofthebagID>': 31110,
#  '<BERTRAM:IDletthegenieoutofthebottleID>': 31111,
#  '<BERTRAM:IDletyourhairdownID>': 31112,
#  '<BERTRAM:IDlielowID>': 31113,
#  '<BERTRAM:IDlifeandlimbID>': 31114,
#  '<BERTRAM:IDliftafingerID>': 31115,
#  '<BERTRAM:IDlikeabatoutofhellID>': 31116,
#  '<BERTRAM:IDlikeclockworkID>': 31117,
#  '<BERTRAM:IDlikepeasinapodID>': 31118,
#  '<BERTRAM:IDliketheclappersID>': 31119,
#  '<BERTRAM:IDlivealieID>': 31120,
#  '<BERTRAM:IDliveandletliveID>': 31121,
#  '<BERTRAM:IDliveinsinID>': 31122,
#  '<BERTRAM:IDliveitupID>': 31123,
#  '<BERTRAM:IDlivewireID>': 31124,
#  '<BERTRAM:IDlockhornsID>': 31125,
#  '<BERTRAM:IDlonewolfID>': 31126,
#  '<BERTRAM:IDlonginthetoothID>': 31127,
#  '<BERTRAM:IDlongtimenoseeID>': 31128,
#  '<BERTRAM:IDlookbeforeyouleapID>': 31129,
#  '<BERTRAM:IDlookonthebrightsideID>': 31130,
#  '<BERTRAM:IDlooktheotherwayID>': 31131,
#  '<BERTRAM:IDlookthepartID>': 31132,
#  '<BERTRAM:IDlosefaceID>': 31133,
#  '<BERTRAM:IDloseheartID>': 31134,
#  '<BERTRAM:IDlosetheplotID>': 31135,
#  '<BERTRAM:IDloseyourheadID>': 31136,
#  '<BERTRAM:IDloseyourshirtID>': 31137,
#  '<BERTRAM:IDmakeacleanbreakID>': 31138,
#  '<BERTRAM:IDmakeagoofID>': 31139,
#  '<BERTRAM:IDmakeakillingID>': 31140,
#  '<BERTRAM:IDmakeamealofID>': 31141,
#  '<BERTRAM:IDmakeamoveID>': 31142,
#  '<BERTRAM:IDmakeanightofitID>': 31143,
#  '<BERTRAM:IDmakeapitchID>': 31144,
#  '<BERTRAM:IDmakeasplashID>': 31145,
#  '<BERTRAM:IDmakeendsmeetID>': 31146,
#  '<BERTRAM:IDmakehayID>': 31147,
#  '<BERTRAM:IDmakelightofID>': 31148,
#  '<BERTRAM:IDmakeorbreakID>': 31149,
#  '<BERTRAM:IDmakeshortworkofID>': 31150,
#  '<BERTRAM:IDmakethecutID>': 31151,
#  '<BERTRAM:IDmakethegradeID>': 31152,
#  '<BERTRAM:IDmaketracksID>': 31153,
#  '<BERTRAM:IDmakewavesID>': 31154,
#  '<BERTRAM:IDmakeyourbloodboilID>': 31155,
#  '<BERTRAM:IDmanandboyID>': 31156,
#  '<BERTRAM:IDmanofgodID>': 31157,
#  '<BERTRAM:IDmarchingordersID>': 31158,
#  '<BERTRAM:IDmarktimeID>': 31159,
#  '<BERTRAM:IDmeanbusinessID>': 31160,
#  '<BERTRAM:IDmeatandpotatoesID>': 31161,
#  '<BERTRAM:IDmeetyourmakerID>': 31162,
#  '<BERTRAM:IDmeetyourmatchID>': 31163,
#  '<BERTRAM:IDmendfencesID>': 31164,
#  '<BERTRAM:IDmisstheboatID>': 31165,
#  '<BERTRAM:IDmomentoftruthID>': 31166,
#  '<BERTRAM:IDmoneyforjamID>': 31167,
#  '<BERTRAM:IDmoveheavenandearthID>': 31168,
#  '<BERTRAM:IDmovemountainsID>': 31169,
#  '<BERTRAM:IDmovethegoalpostsID>': 31170,
#  '<BERTRAM:IDmuchofamuchnessID>': 31171,
#  '<BERTRAM:IDmuddythewatersID>': 31172,
#  '<BERTRAM:IDmybadID>': 31173,
#  '<BERTRAM:IDnamenamesID>': 31174,
#  '<BERTRAM:IDneartheknuckleID>': 31175,
#  '<BERTRAM:IDneckandneckID>': 31176,
#  '<BERTRAM:IDneckofthewoodsID>': 31177,
#  '<BERTRAM:IDneitherfishnorfowlID>': 31178,
#  '<BERTRAM:IDneitherherenorthereID>': 31179,
#  '<BERTRAM:IDneversaydieID>': 31180,
#  '<BERTRAM:IDneverthetwainshallmeetID>': 31181,
#  '<BERTRAM:IDnewbloodID>': 31182,
#  '<BERTRAM:IDniceaspieID>': 31183,
#  '<BERTRAM:IDninetimesoutoftenID>': 31184,
#  '<BERTRAM:IDnipandtuckID>': 31185,
#  '<BERTRAM:IDnocandoID>': 31186,
#  '<BERTRAM:IDnodiceID>': 31187,
#  '<BERTRAM:IDnogreatshakesID>': 31188,
#  '<BERTRAM:IDnolaughingmatterID>': 31189,
#  '<BERTRAM:IDnorestforthewickedID>': 31190,
#  '<BERTRAM:IDnospringchickenID>': 31191,
#  '<BERTRAM:IDnosweatID>': 31192,
#  '<BERTRAM:IDnotallthereID>': 31193,
#  '<BERTRAM:IDnotbataneyeID>': 31194,
#  '<BERTRAM:IDnotcricketID>': 31195,
#  '<BERTRAM:IDnotgiveafigID>': 31196,
#  '<BERTRAM:IDnothingdoingID>': 31197,
#  '<BERTRAM:IDnothingtoitID>': 31198,
#  '<BERTRAM:IDnothingtowritehomeaboutID>': 31199,
#  '<BERTRAM:IDnotimelikethepresentID>': 31200,
#  '<BERTRAM:IDnottobesneezedatID>': 31201,
#  '<BERTRAM:IDnottoputtoofineapointonitID>': 31202,
#  '<BERTRAM:IDnotwowaysaboutitID>': 31203,
#  '<BERTRAM:IDnoworneverID>': 31204,
#  '<BERTRAM:IDnudgenudgewinkwinkID>': 31205,
#  '<BERTRAM:IDoddoneoutID>': 31206,
#  '<BERTRAM:IDoffandonID>': 31207,
#  '<BERTRAM:IDoffandrunningID>': 31208,
#  '<BERTRAM:IDoffthebeatentrackID>': 31209,
#  '<BERTRAM:IDoffthecuffID>': 31210,
#  '<BERTRAM:IDoffthehookID>': 31211,
#  '<BERTRAM:IDoffthemarkID>': 31212,
#  '<BERTRAM:IDofftherecordID>': 31213,
#  '<BERTRAM:IDofftheshelfID>': 31214,
#  '<BERTRAM:IDoffthetopofyourheadID>': 31215,
#  '<BERTRAM:IDoffthewallID>': 31216,
#  '<BERTRAM:IDoilandwaterID>': 31217,
#  '<BERTRAM:IDoldasthehillsID>': 31218,
#  '<BERTRAM:IDoldhatID>': 31219,
#  '<BERTRAM:IDonafullstomachID>': 31220,
#  '<BERTRAM:IDonandoffID>': 31221,
#  '<BERTRAM:IDonarollID>': 31222,
#  '<BERTRAM:IDonasilverplatterID>': 31223,
#  '<BERTRAM:IDonboardID>': 31224,
#  '<BERTRAM:IDonceandforallID>': 31225,
#  '<BERTRAM:IDonceinabluemoonID>': 31226,
#  '<BERTRAM:IDonceinawhileID>': 31227,
#  '<BERTRAM:IDoncloudnineID>': 31228,
#  '<BERTRAM:IDoneandthesameID>': 31229,
#  '<BERTRAM:IDonedgeID>': 31230,
#  '<BERTRAM:IDonefortheroadID>': 31231,
#  '<BERTRAM:IDonegoodturndeservesanotherID>': 31232,
#  '<BERTRAM:IDoneofthosedaysID>': 31233,
#  '<BERTRAM:IDoneofthosethingsID>': 31234,
#  '<BERTRAM:IDoniceID>': 31235,
#  '<BERTRAM:IDonpaperID>': 31236,
#  '<BERTRAM:IDontenterhooksID>': 31237,
#  '<BERTRAM:IDonthebackburnerID>': 31238,
#  '<BERTRAM:IDonthebackofID>': 31239,
#  '<BERTRAM:IDontheballID>': 31240,
#  '<BERTRAM:IDonthebounceID>': 31241,
#  '<BERTRAM:IDonthebuttonID>': 31242,
#  '<BERTRAM:IDonthecardsID>': 31243,
#  '<BERTRAM:IDonthecarpetID>': 31244,
#  '<BERTRAM:IDonthecuffID>': 31245,
#  '<BERTRAM:IDonthedotID>': 31246,
#  '<BERTRAM:IDonthedoubleID>': 31247,
#  '<BERTRAM:IDonthefaceofitID>': 31248,
#  '<BERTRAM:IDonthefiddleID>': 31249,
#  '<BERTRAM:IDontheflyID>': 31250,
#  '<BERTRAM:IDonthegameID>': 31251,
#  '<BERTRAM:IDonthehoofID>': 31252,
#  '<BERTRAM:IDonthehopID>': 31253,
#  '<BERTRAM:IDonthehornID>': 31254,
#  '<BERTRAM:IDonthehornsofadilemmaID>': 31255,
#  '<BERTRAM:IDonthehouseID>': 31256,
#  '<BERTRAM:IDonthelamID>': 31257,
#  '<BERTRAM:IDonthelevelID>': 31258,
#  '<BERTRAM:IDonthemendID>': 31259,
#  '<BERTRAM:IDonthemoneyID>': 31260,
#  '<BERTRAM:IDonthenodID>': 31261,
#  '<BERTRAM:IDonthenoseID>': 31262,
#  '<BERTRAM:IDonthepullID>': 31263,
#  '<BERTRAM:IDonthereboundID>': 31264,
#  '<BERTRAM:IDontherocksID>': 31265,
#  '<BERTRAM:IDontheropesID>': 31266,
#  '<BERTRAM:IDontherunID>': 31267,
#  '<BERTRAM:IDonthesamepageID>': 31268,
#  '<BERTRAM:IDonthesamewavelengthID>': 31269,
#  '<BERTRAM:IDontheshelfID>': 31270,
#  '<BERTRAM:IDonthesideoftheangelsID>': 31271,
#  '<BERTRAM:IDontheskidsID>': 31272,
#  '<BERTRAM:IDonthespurofthemomentID>': 31273,
#  '<BERTRAM:IDonthesquareID>': 31274,
#  '<BERTRAM:IDonthestumpID>': 31275,
#  '<BERTRAM:IDonthetakeID>': 31276,
#  '<BERTRAM:IDonthetrotID>': 31277,
#  '<BERTRAM:IDontheupandupID>': 31278,
#  '<BERTRAM:IDonthewagonID>': 31279,
#  '<BERTRAM:IDonthewarpathID>': 31280,
#  '<BERTRAM:IDonthiniceID>': 31281,
#  '<BERTRAM:IDonyourtoesID>': 31282,
#  '<BERTRAM:IDopenthefloodgatesID>': 31283,
#  '<BERTRAM:IDoutandaboutID>': 31284,
#  '<BERTRAM:IDoutcoldID>': 31285,
#  '<BERTRAM:IDoutofkilterID>': 31286,
#  '<BERTRAM:IDoutoflineID>': 31287,
#  '<BERTRAM:IDoutoforderID>': 31288,
#  '<BERTRAM:IDoutofpocketID>': 31289,
#  '<BERTRAM:IDoutofsightID>': 31290,
#  '<BERTRAM:IDoutofsortsID>': 31291,
#  '<BERTRAM:IDoutoftheboxID>': 31292,
#  '<BERTRAM:IDoutoftheloopID>': 31293,
#  '<BERTRAM:IDoutofthepictureID>': 31294,
#  '<BERTRAM:IDoutofthequestionID>': 31295,
#  '<BERTRAM:IDoutoftherunningID>': 31296,
#  '<BERTRAM:IDoutofthewoodsID>': 31297,
#  '<BERTRAM:IDoutofthinairID>': 31298,
#  '<BERTRAM:IDoutofwhackID>': 31299,
#  '<BERTRAM:IDoutofyourmindID>': 31300,
#  '<BERTRAM:IDoutonalimbID>': 31301,
#  '<BERTRAM:IDouttolunchID>': 31302,
#  '<BERTRAM:IDoverthecounterID>': 31303,
#  '<BERTRAM:IDoverthehillID>': 31304,
#  '<BERTRAM:IDoverthemoonID>': 31305,
#  '<BERTRAM:IDoverthetopID>': 31306,
#  '<BERTRAM:IDoveryourheadID>': 31307,
#  '<BERTRAM:IDpackapunchID>': 31308,
#  '<BERTRAM:IDpaintthetownredID>': 31309,
#  '<BERTRAM:IDpaperoverthecracksID>': 31310,
#  '<BERTRAM:IDparforthecourseID>': 31311,
#  '<BERTRAM:IDpartofthefurnitureID>': 31312,
#  '<BERTRAM:IDpassmusterID>': 31313,
#  '<BERTRAM:IDpassthebuckID>': 31314,
#  '<BERTRAM:IDpassthetimeofdayID>': 31315,
#  '<BERTRAM:IDpaythepiperID>': 31316,
#  '<BERTRAM:IDpaythroughthenoseID>': 31317,
#  '<BERTRAM:IDpeachesandcreamID>': 31318,
#  '<BERTRAM:IDpeckingorderID>': 31319,
#  '<BERTRAM:IDperishthethoughtID>': 31320,
#  '<BERTRAM:IDpickholesID>': 31321,
#  '<BERTRAM:IDpickupthepiecesID>': 31322,
#  '<BERTRAM:IDpickupthetabID>': 31323,
#  '<BERTRAM:IDpieintheskyID>': 31324,
#  '<BERTRAM:IDpissedoffID>': 31325,
#  '<BERTRAM:IDplaceinthesunID>': 31326,
#  '<BERTRAM:IDplainjaneID>': 31327,
#  '<BERTRAM:IDplainsailingID>': 31328,
#  '<BERTRAM:IDplanbID>': 31329,
#  '<BERTRAM:IDplayballID>': 31330,
#  '<BERTRAM:IDplayfastandlooseID>': 31331,
#  '<BERTRAM:IDplayfortimeID>': 31332,
#  '<BERTRAM:IDplaygamesID>': 31333,
#  '<BERTRAM:IDplayhardtogetID>': 31334,
#  '<BERTRAM:IDplayitcoolID>': 31335,
#  '<BERTRAM:IDplayitsafeID>': 31336,
#  '<BERTRAM:IDplaythefieldID>': 31337,
#  '<BERTRAM:IDplaywithfireID>': 31338,
#  '<BERTRAM:IDpleasedaspunchID>': 31339,
#  '<BERTRAM:IDpointthefingerID>': 31340,
#  '<BERTRAM:IDpoorasachurchmouseID>': 31341,
#  '<BERTRAM:IDpoorlittlerichgirlID>': 31342,
#  '<BERTRAM:IDpopthequestionID>': 31343,
#  '<BERTRAM:IDpoundthepavementID>': 31344,
#  '<BERTRAM:IDpourcoldwateronID>': 31345,
#  '<BERTRAM:IDpowerbehindthethroneID>': 31346,
#  '<BERTRAM:IDpresenceofmindID>': 31347,
#  '<BERTRAM:IDpressthefleshID>': 31348,
#  '<BERTRAM:IDpressthepanicbuttonID>': 31349,
#  '<BERTRAM:IDprickupyourearsID>': 31350,
#  '<BERTRAM:IDprodigalsonID>': 31351,
#  '<BERTRAM:IDpullafastoneID>': 31352,
#  '<BERTRAM:IDpulloutallthestopsID>': 31353,
#  '<BERTRAM:IDpullrankID>': 31354,
#  '<BERTRAM:IDpullstringsID>': 31355,
#  '<BERTRAM:IDpulltheplugID>': 31356,
#  '<BERTRAM:IDpullupstakesID>': 31357,
#  '<BERTRAM:IDpullyourweightID>': 31358,
#  '<BERTRAM:IDpumpironID>': 31359,
#  '<BERTRAM:IDpureandsimpleID>': 31360,
#  '<BERTRAM:IDpushtheboatoutID>': 31361,
#  '<BERTRAM:IDpushtheenvelopeID>': 31362,
#  '<BERTRAM:IDpushthepanicbuttonID>': 31363,
#  '<BERTRAM:IDputadamperonID>': 31364,
#  '<BERTRAM:IDputafootwrongID>': 31365,
#  '<BERTRAM:IDputasockinitID>': 31366,
#  '<BERTRAM:IDputdownrootsID>': 31367,
#  '<BERTRAM:IDputpaidtoID>': 31368,
#  '<BERTRAM:IDputthebootinID>': 31369,
#  '<BERTRAM:IDputthecartbeforethehorseID>': 31370,
#  '<BERTRAM:IDputthecatamongthepigeonsID>': 31371,
#  '<BERTRAM:IDputthekiboshonID>': 31372,
#  '<BERTRAM:IDputuporshutupID>': 31373,
#  '<BERTRAM:IDputyourbestfootforwardID>': 31374,
#  '<BERTRAM:IDputyourfootdownID>': 31375,
#  '<BERTRAM:IDquickasaflashID>': 31376,
#  '<BERTRAM:IDquietasamouseID>': 31377,
#  '<BERTRAM:IDrainorshineID>': 31378,
#  '<BERTRAM:IDraisecainID>': 31379,
#  '<BERTRAM:IDraisehellID>': 31380,
#  '<BERTRAM:IDraisetheroofID>': 31381,
#  '<BERTRAM:IDrankandfileID>': 31382,
#  '<BERTRAM:IDreachforthestarsID>': 31383,
#  '<BERTRAM:IDreadbetweenthelinesID>': 31384,
#  '<BERTRAM:IDreadmylipsID>': 31385,
#  '<BERTRAM:IDredsunderthebedID>': 31386,
#  '<BERTRAM:IDreinventthewheelID>': 31387,
#  '<BERTRAM:IDrestonyourlaurelsID>': 31388,
#  '<BERTRAM:IDrhymeorreasonID>': 31389,
#  '<BERTRAM:IDridehighID>': 31390,
#  '<BERTRAM:IDrideroughshodoverID>': 31391,
#  '<BERTRAM:IDrideshotgunID>': 31392,
#  '<BERTRAM:IDridetherailsID>': 31393,
#  '<BERTRAM:IDrightasrainID>': 31394,
#  '<BERTRAM:IDrightupyourstreetID>': 31395,
#  '<BERTRAM:IDringabellID>': 31396,
#  '<BERTRAM:IDriseandshineID>': 31397,
#  '<BERTRAM:IDrisefromtheashesID>': 31398,
#  '<BERTRAM:IDrisethroughtheranksID>': 31399,
#  '<BERTRAM:IDrisetotheoccasionID>': 31400,
#  '<BERTRAM:IDrobpetertopaypaulID>': 31401,
#  '<BERTRAM:IDrockbottomID>': 31402,
#  '<BERTRAM:IDrocktheboatID>': 31403,
#  '<BERTRAM:IDrollupyoursleevesID>': 31404,
#  '<BERTRAM:IDrollwiththepunchesID>': 31405,
#  '<BERTRAM:IDroughandtumbleID>': 31406,
#  '<BERTRAM:IDrougharoundtheedgesID>': 31407,
#  '<BERTRAM:IDroughedgesID>': 31408,
#  '<BERTRAM:IDroundthebendID>': 31409,
#  '<BERTRAM:IDroundtheclockID>': 31410,
#  '<BERTRAM:IDrubshouldersID>': 31411,
#  '<BERTRAM:IDruleofthumbID>': 31412,
#  '<BERTRAM:IDruletheroostID>': 31413,
#  '<BERTRAM:IDrunamileID>': 31414,
#  '<BERTRAM:IDrunamokID>': 31415,
#  '<BERTRAM:IDrunbeforeyoucanwalkID>': 31416,
#  '<BERTRAM:IDrunintothesandID>': 31417,
#  '<BERTRAM:IDrunoutofgasID>': 31418,
#  '<BERTRAM:IDrunoutofsteamID>': 31419,
#  '<BERTRAM:IDrunriotID>': 31420,
#  '<BERTRAM:IDrunthegamutID>': 31421,
#  '<BERTRAM:IDrunthegauntletID>': 31422,
#  '<BERTRAM:IDsadsackID>': 31423,
#  '<BERTRAM:IDsafeashousesID>': 31424,
#  '<BERTRAM:IDsamedifferenceID>': 31425,
#  '<BERTRAM:IDsavedbythebellID>': 31426,
#  '<BERTRAM:IDsavefaceID>': 31427,
#  '<BERTRAM:IDsavethedayID>': 31428,
#  '<BERTRAM:IDsaycheeseID>': 31429,
#  '<BERTRAM:IDsayuncleID>': 31430,
#  '<BERTRAM:IDscarletwomanID>': 31431,
#  '<BERTRAM:IDscratchthesurfaceID>': 31432,
#  '<BERTRAM:IDscreambluemurderID>': 31433,
#  '<BERTRAM:IDsecondchildhoodID>': 31434,
#  '<BERTRAM:IDseeeyetoeyeID>': 31435,
#  '<BERTRAM:IDseenbetterdaysID>': 31436,
#  '<BERTRAM:IDseeredID>': 31437,
#  '<BERTRAM:IDseestarsID>': 31438,
#  '<BERTRAM:IDseetheelephantID>': 31439,
#  '<BERTRAM:IDseethelightID>': 31440,
#  '<BERTRAM:IDseethelightofdayID>': 31441,
#  '<BERTRAM:IDseizethedayID>': 31442,
#  '<BERTRAM:IDselllikehotcakesID>': 31443,
#  '<BERTRAM:IDsellyoursoulID>': 31444,
#  '<BERTRAM:IDseparatethewheatfromthechaffID>': 31445,
#  '<BERTRAM:IDseteyesonID>': 31446,
#  '<BERTRAM:IDsetthewheelsinmotionID>': 31447,
#  '<BERTRAM:IDsettleascoreID>': 31448,
#  '<BERTRAM:IDsetyoursightsonID>': 31449,
#  '<BERTRAM:IDshakealegID>': 31450,
#  '<BERTRAM:IDshipshapeandbristolfashionID>': 31451,
#  '<BERTRAM:IDshootfromthehipID>': 31452,
#  '<BERTRAM:IDshootthebreezeID>': 31453,
#  '<BERTRAM:IDshootthebullID>': 31454,
#  '<BERTRAM:IDshootthemessengerID>': 31455,
#  '<BERTRAM:IDshortshriftID>': 31456,
#  '<BERTRAM:IDshowtheflagID>': 31457,
#  '<BERTRAM:IDshrinkingvioletID>': 31458,
#  '<BERTRAM:IDshuffleoffthismortalcoilID>': 31459,
#  '<BERTRAM:IDshutthedooronID>': 31460,
#  '<BERTRAM:IDsickandtiredID>': 31461,
#  '<BERTRAM:IDsickasadogID>': 31462,
#  '<BERTRAM:IDsicktodeathID>': 31463,
#  '<BERTRAM:IDsignofthetimesID>': 31464,
#  '<BERTRAM:IDsilenceisgoldenID>': 31465,
#  '<BERTRAM:IDsingthepraisesofID>': 31466,
#  '<BERTRAM:IDsinkorswimID>': 31467,
#  '<BERTRAM:IDsitonthefenceID>': 31468,
#  '<BERTRAM:IDsittightID>': 31469,
#  '<BERTRAM:IDsittingduckID>': 31470,
#  '<BERTRAM:IDsixfeetunderID>': 31471,
#  '<BERTRAM:IDslaponthewristID>': 31472,
#  '<BERTRAM:IDsleeproughID>': 31473,
#  '<BERTRAM:IDsleightofhandID>': 31474,
#  '<BERTRAM:IDslipofthetongueID>': 31475,
#  '<BERTRAM:IDslipthroughthenetID>': 31476,
#  '<BERTRAM:IDslowburnID>': 31477,
#  '<BERTRAM:IDsmallbeerID>': 31478,
#  '<BERTRAM:IDsmallpotatoesID>': 31479,
#  '<BERTRAM:IDsmallprintID>': 31480,
#  '<BERTRAM:IDsmartalecID>': 31481,
#  '<BERTRAM:IDsmellaratID>': 31482,
#  '<BERTRAM:IDsmellbloodID>': 31483,
#  '<BERTRAM:IDsmokeandmirrorsID>': 31484,
#  '<BERTRAM:IDsonganddanceID>': 31485,
#  '<BERTRAM:IDsourgrapesID>': 31486,
#  '<BERTRAM:IDsparetherodandspoilthechildID>': 31487,
#  '<BERTRAM:IDspeakvolumesID>': 31488,
#  '<BERTRAM:IDspeakyourmindID>': 31489,
#  '<BERTRAM:IDspillthebeansID>': 31490,
#  '<BERTRAM:IDspinayarnID>': 31491,
#  '<BERTRAM:IDspitbloodID>': 31492,
#  '<BERTRAM:IDspititoutID>': 31493,
#  '<BERTRAM:IDsplithairsID>': 31494,
#  '<BERTRAM:IDsplitthedifferenceID>': 31495,
#  '<BERTRAM:IDspotonID>': 31496,
#  '<BERTRAM:IDspreadyourselftoothinID>': 31497,
#  '<BERTRAM:IDspringtomindID>': 31498,
#  '<BERTRAM:IDstakeaclaimID>': 31499,
#  '<BERTRAM:IDstandthetestoftimeID>': 31500,
#  '<BERTRAM:IDstandupandbecountedID>': 31501,
#  '<BERTRAM:IDstartoffontherightfootID>': 31502,
#  '<BERTRAM:IDstartoffonthewrongfootID>': 31503,
#  '<BERTRAM:IDstateoftheartID>': 31504,
#  '<BERTRAM:IDstaythecourseID>': 31505,
#  '<BERTRAM:IDstealtheshowID>': 31506,
#  '<BERTRAM:IDsteerclearofID>': 31507,
#  '<BERTRAM:IDsteponitID>': 31508,
#  '<BERTRAM:IDstickoutlikeasorethumbID>': 31509,
#  '<BERTRAM:IDsticktoyourgunsID>': 31510,
#  '<BERTRAM:IDstickyourneckoutID>': 31511,
#  '<BERTRAM:IDstopatnothingID>': 31512,
#  '<BERTRAM:IDstrikeachordID>': 31513,
#  '<BERTRAM:IDstrikeitrichID>': 31514,
#  '<BERTRAM:IDstrikewhiletheironishotID>': 31515,
#  '<BERTRAM:IDstrokeofluckID>': 31516,
#  '<BERTRAM:IDstubbornasamuleID>': 31517,
#  '<BERTRAM:IDsweatbloodID>': 31518,
#  '<BERTRAM:IDsweeptheboardID>': 31519,
#  '<BERTRAM:IDsweetnessandlightID>': 31520,
#  '<BERTRAM:IDsweetnothingsID>': 31521,
#  ...}

# %%
# Test for MWE single-tokens
test_tokens = ['<BERTRAM:IDoffthebeatentrackID>', '<BERTRAM:IDchapterandverseID>', '<BERTRAM:IDjointheclubID>', '<BERTRAM:IDtietheknotID>']

# %%
for token in test_tokens:
    assert tokenizer.tokenize(f'This is a {token}')[-1] == token, f"Error:{token} not detected"
    print(tokenizer.tokenize(f'This is a {token}'))

print(f'SUCCESS!! The {SeqClassification_model_path} tokenizer model has been tested!!')
# Out:
# ['this', 'is', 'a', '<BERTRAM:IDoffthebeatentrackID>']
# ['this', 'is', 'a', '<BERTRAM:IDchapterandverseID>']
# ['this', 'is', 'a', '<BERTRAM:IDjointheclubID>']
# ['this', 'is', 'a', '<BERTRAM:IDtietheknotID>']
# SUCCESS!! The ../../local_models/bert-base-uncased_option1_with_bertram_SC tokenizer model has been tested!!

# %%
# TEST THE SequenceClassification model
def get_model_predictions(sents):
    inputs=tokenizer(sents, padding=True, truncation=True, return_tensors="pt")
    outputs = model(**inputs) 
    logits = outputs.logits
    print(logits)
    predictions = torch.argmax(logits, dim=-1)
    return predictions

sents = [f'This {token} is very very bad', f'This is a {token} with very long sentence!']
for token in test_tokens:
    for sent in sents:
        preds = get_model_predictions([sent])
        print(f"Input token:{token} \nPredictions:{preds}")
        print('-'*30)
# Out:
# tensor([[-0.3069,  0.3080]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDoffthebeatentrackID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3760,  0.2061]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDoffthebeatentrackID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3069,  0.3080]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDchapterandverseID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3760,  0.2061]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDchapterandverseID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3069,  0.3080]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDjointheclubID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3760,  0.2061]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDjointheclubID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3069,  0.3080]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDtietheknotID>
# Predictions:tensor([1])
# ------------------------------
# tensor([[-0.3760,  0.2061]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDtietheknotID>
# Predictions:tensor([1])
# ------------------------------
