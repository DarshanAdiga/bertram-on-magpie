# %% [markdown]
# # Convert MaskedLM model to a SequenceClassification model

# %%
import torch
from transformers import AutoModelForMaskedLM, AutoModelForSequenceClassification
from transformers import AutoTokenizer

import os

# %%
local_model_base_dir = '../local_models/'

# %%
MaskedLM_model_path = local_model_base_dir + 'bert-base-uncased_option1_with_bertram_bt2'
SeqClassification_model_path = local_model_base_dir + 'bert-base-uncased_option1_with_bertram_bt2_SC'

# %%
if os.path.exists(SeqClassification_model_path):
    err = f"Error! Directory {SeqClassification_model_path} already exists!"
    raise Exception(err)

# %% [markdown]
# ## Load as Masked LM and save as SequenceClassification model

# %%
print(f"Going to load the MaskedLM model from {MaskedLM_model_path} and convert it into a SequenceClassification \
model and save it at {SeqClassification_model_path}")
# Out:
# Going to load the MaskedLM model from ../local_models/bert-base-uncased_option1_with_bertram_bt2 and convert it into a SequenceClassification model and save it at ../local_models/bert-base-uncased_option1_with_bertram_bt2_SC

# %%
# Load the models
model = AutoModelForSequenceClassification.from_pretrained(MaskedLM_model_path)
tokenizer = AutoTokenizer.from_pretrained(MaskedLM_model_path, use_fast=False, truncation=True)
# Out:
# Some weights of the model checkpoint at ../local_models/bert-base-uncased_option1_with_bertram_bt2 were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at ../local_models/bert-base-uncased_option1_with_bertram_bt2 and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# Save the models
model.save_pretrained(SeqClassification_model_path)
tokenizer.save_pretrained(SeqClassification_model_path)
print(f"Saved the SequenceClassification model at {SeqClassification_model_path}")
# Out:
# Saved the SequenceClassification model at ../local_models/bert-base-uncased_option1_with_bertram_bt2_SC

# %% [markdown]
# ## Test the Tokenizer & SequenceClassification model

# %%
tokenizer.get_added_vocab()
# Out:
# {'<BERTRAM:IDaboveboardID>': 30522,
#  '<BERTRAM:IDaboveparID>': 30523,
#  '<BERTRAM:IDacrosstheboardID>': 30524,
#  '<BERTRAM:IDaddfueltothefireID>': 30525,
#  '<BERTRAM:IDagainstthegrainID>': 30526,
#  '<BERTRAM:IDaheadofthecurveID>': 30527,
#  '<BERTRAM:IDaheadofthegameID>': 30528,
#  '<BERTRAM:IDalittlebirdtoldmeID>': 30529,
#  '<BERTRAM:IDallalongID>': 30530,
#  '<BERTRAM:IDallbetsareoffID>': 30531,
#  '<BERTRAM:IDalldressedupandnowheretogoID>': 30532,
#  '<BERTRAM:IDallhellbrokelooseID>': 30533,
#  '<BERTRAM:IDalloverbartheshoutingID>': 30534,
#  '<BERTRAM:IDalloverthemapID>': 30535,
#  '<BERTRAM:IDallovertheplaceID>': 30536,
#  '<BERTRAM:IDallovertheshopID>': 30537,
#  '<BERTRAM:IDallovertheshowID>': 30538,
#  '<BERTRAM:IDalltherageID>': 30539,
#  '<BERTRAM:IDallthingsbeingequalID>': 30540,
#  '<BERTRAM:IDallwetID>': 30541,
#  '<BERTRAM:IDalongaboutID>': 30542,
#  '<BERTRAM:IDandallthatjazzID>': 30543,
#  '<BERTRAM:IDandthensomeID>': 30544,
#  '<BERTRAM:IDanoldflameID>': 30545,
#  '<BERTRAM:IDarguethetossID>': 30546,
#  '<BERTRAM:IDarmedtotheteethID>': 30547,
#  '<BERTRAM:IDaroundtheclockID>': 30548,
#  '<BERTRAM:IDasaruleID>': 30549,
#  '<BERTRAM:IDasgoodasnewID>': 30550,
#  '<BERTRAM:IDaskforthemoonID>': 30551,
#  '<BERTRAM:IDasleepatthewheelID>': 30552,
#  '<BERTRAM:IDasluckwouldhaveitID>': 30553,
#  '<BERTRAM:IDasthecrowfliesID>': 30554,
#  '<BERTRAM:IDatacanterID>': 30555,
#  '<BERTRAM:IDatalooseendID>': 30556,
#  '<BERTRAM:IDatalossforwordsID>': 30557,
#  '<BERTRAM:IDatapinchID>': 30558,
#  '<BERTRAM:IDatastretchID>': 30559,
#  '<BERTRAM:IDatcrosspurposesID>': 30560,
#  '<BERTRAM:IDatdaggersdrawnID>': 30561,
#  '<BERTRAM:IDatloggerheadsID>': 30562,
#  '<BERTRAM:IDatseaID>': 30563,
#  '<BERTRAM:IDatsixesandsevensID>': 30564,
#  '<BERTRAM:IDatthecoalfaceID>': 30565,
#  '<BERTRAM:IDatthecrossroadsID>': 30566,
#  '<BERTRAM:IDatthedropofahatID>': 30567,
#  '<BERTRAM:IDattheendofthedayID>': 30568,
#  '<BERTRAM:IDatyourfingertipsID>': 30569,
#  '<BERTRAM:IDawaywiththefairiesID>': 30570,
#  '<BERTRAM:IDbabeinarmsID>': 30571,
#  '<BERTRAM:IDbacktosquareoneID>': 30572,
#  '<BERTRAM:IDbacktothedrawingboardID>': 30573,
#  '<BERTRAM:IDbagandbaggageID>': 30574,
#  '<BERTRAM:IDbangforthebuckID>': 30575,
#  '<BERTRAM:IDbangtorightsID>': 30576,
#  '<BERTRAM:IDbarkupthewrongtreeID>': 30577,
#  '<BERTRAM:IDbarnoneID>': 30578,
#  '<BERTRAM:IDbasketcaseID>': 30579,
#  '<BERTRAM:IDbeallearsID>': 30580,
#  '<BERTRAM:IDbearfruitID>': 30581,
#  '<BERTRAM:IDbearinmindID>': 30582,
#  '<BERTRAM:IDbeataboutthebushID>': 30583,
#  '<BERTRAM:IDbeattheclockID>': 30584,
#  '<BERTRAM:IDbeatthedaylightsoutofID>': 30585,
#  '<BERTRAM:IDbeatthemeatID>': 30586,
#  '<BERTRAM:IDbeattherapID>': 30587,
#  '<BERTRAM:IDbedroomeyesID>': 30588,
#  '<BERTRAM:IDbeerandskittlesID>': 30589,
#  '<BERTRAM:IDbegthequestionID>': 30590,
#  '<BERTRAM:IDbehindbarsID>': 30591,
#  '<BERTRAM:IDbehindcloseddoorsID>': 30592,
#  '<BERTRAM:IDbehindthecurveID>': 30593,
#  '<BERTRAM:IDbehindtheeightballID>': 30594,
#  '<BERTRAM:IDbehindthescenesID>': 30595,
#  '<BERTRAM:IDbellthecatID>': 30596,
#  '<BERTRAM:IDbelowparID>': 30597,
#  '<BERTRAM:IDbelowthebeltID>': 30598,
#  '<BERTRAM:IDbeltandbracesID>': 30599,
#  '<BERTRAM:IDbemyguestID>': 30600,
#  '<BERTRAM:IDbesideyourselfID>': 30601,
#  '<BERTRAM:IDbetterthedevilyouknowID>': 30602,
#  '<BERTRAM:IDbetweenarockandahardplaceID>': 30603,
#  '<BERTRAM:IDbetweenthedevilandthedeepblueseaID>': 30604,
#  '<BERTRAM:IDbetwixtandbetweenID>': 30605,
#  '<BERTRAM:IDbeyondthepaleID>': 30606,
#  '<BERTRAM:IDbighitterID>': 30607,
#  '<BERTRAM:IDbirdsofafeatherID>': 30608,
#  '<BERTRAM:IDbiteoffmorethanyoucanchewID>': 30609,
#  '<BERTRAM:IDbitethebigoneID>': 30610,
#  '<BERTRAM:IDbitethebulletID>': 30611,
#  '<BERTRAM:IDbitethedustID>': 30612,
#  '<BERTRAM:IDbiteyourlipID>': 30613,
#  '<BERTRAM:IDbiteyourtongueID>': 30614,
#  '<BERTRAM:IDblackandblueID>': 30615,
#  '<BERTRAM:IDblazeatrailID>': 30616,
#  '<BERTRAM:IDbleedingheartID>': 30617,
#  '<BERTRAM:IDbloodandgutsID>': 30618,
#  '<BERTRAM:IDbloodandthunderID>': 30619,
#  '<BERTRAM:IDbloodisthickerthanwaterID>': 30620,
#  '<BERTRAM:IDblowafuseID>': 30621,
#  '<BERTRAM:IDblowagasketID>': 30622,
#  '<BERTRAM:IDblowhotandcoldID>': 30623,
#  '<BERTRAM:IDblowoffsteamID>': 30624,
#  '<BERTRAM:IDbootsandallID>': 30625,
#  '<BERTRAM:IDbornandbredID>': 30626,
#  '<BERTRAM:IDboyswillbeboysID>': 30627,
#  '<BERTRAM:IDbrassmonkeyID>': 30628,
#  '<BERTRAM:IDbrassneckID>': 30629,
#  '<BERTRAM:IDbreadandcircusesID>': 30630,
#  '<BERTRAM:IDbreakcoverID>': 30631,
#  '<BERTRAM:IDbreakevenID>': 30632,
#  '<BERTRAM:IDbreaknewgroundID>': 30633,
#  '<BERTRAM:IDbreakranksID>': 30634,
#  '<BERTRAM:IDbreakthebackofID>': 30635,
#  '<BERTRAM:IDbreakthebankID>': 30636,
#  '<BERTRAM:IDbreaktheiceID>': 30637,
#  '<BERTRAM:IDbrightyoungthingID>': 30638,
#  '<BERTRAM:IDbringhomethebaconID>': 30639,
#  '<BERTRAM:IDbringthehousedownID>': 30640,
#  '<BERTRAM:IDbringuptherearID>': 30641,
#  '<BERTRAM:IDbrowniepointID>': 30642,
#  '<BERTRAM:IDbuggerallID>': 30643,
#  '<BERTRAM:IDbumsteerID>': 30644,
#  '<BERTRAM:IDbundleofjoyID>': 30645,
#  '<BERTRAM:IDburnrubberID>': 30646,
#  '<BERTRAM:IDburnthecandleatbothendsID>': 30647,
#  '<BERTRAM:IDburnthemidnightoilID>': 30648,
#  '<BERTRAM:IDbushtelegraphID>': 30649,
#  '<BERTRAM:IDbuythefarmID>': 30650,
#  '<BERTRAM:IDbuytimeID>': 30651,
#  '<BERTRAM:IDbyalongchalkID>': 30652,
#  '<BERTRAM:IDbyalongshotID>': 30653,
#  '<BERTRAM:IDbyandlargeID>': 30654,
#  '<BERTRAM:IDbydintofID>': 30655,
#  '<BERTRAM:IDbyheartID>': 30656,
#  '<BERTRAM:IDbyhookorbycrookID>': 30657,
#  '<BERTRAM:IDbyleapsandboundsID>': 30658,
#  '<BERTRAM:IDbythebackdoorID>': 30659,
#  '<BERTRAM:IDbythebookID>': 30660,
#  '<BERTRAM:IDbythebyID>': 30661,
#  '<BERTRAM:IDbynostretchoftheimaginationID>': 30662,
#  '<BERTRAM:IDbythesametokenID>': 30663,
#  '<BERTRAM:IDbytheseatofyourpantsID>': 30664,
#  '<BERTRAM:IDbytheskinofyourteethID>': 30665,
#  '<BERTRAM:IDcakesandaleID>': 30666,
#  '<BERTRAM:IDcallaspadeaspadeID>': 30667,
#  '<BERTRAM:IDcallitadayID>': 30668,
#  '<BERTRAM:IDcallitquitsID>': 30669,
#  '<BERTRAM:IDcalltheshotsID>': 30670,
#  '<BERTRAM:IDcallthetuneID>': 30671,
#  '<BERTRAM:IDcapinhandID>': 30672,
#  '<BERTRAM:IDcarrotandstickID>': 30673,
#  '<BERTRAM:IDcarrythedayID>': 30674,
#  '<BERTRAM:IDcastthefirststoneID>': 30675,
#  '<BERTRAM:IDcatchfireID>': 30676,
#  '<BERTRAM:IDcatchthesunID>': 30677,
#  '<BERTRAM:IDchampatthebitID>': 30678,
#  '<BERTRAM:IDchangeyourtuneID>': 30679,
#  '<BERTRAM:IDchapterandverseID>': 30680,
#  '<BERTRAM:IDchaserainbowsID>': 30681,
#  '<BERTRAM:IDcheekbyjowlID>': 30682,
#  '<BERTRAM:IDchewthecudID>': 30683,
#  '<BERTRAM:IDchewthefatID>': 30684,
#  '<BERTRAM:IDchickenfeedID>': 30685,
#  '<BERTRAM:IDchickenscomehometoroostID>': 30686,
#  '<BERTRAM:IDchopandchangeID>': 30687,
#  '<BERTRAM:IDchuckitdownID>': 30688,
#  '<BERTRAM:IDclaimtofameID>': 30689,
#  '<BERTRAM:IDcleanasawhistleID>': 30690,
#  '<BERTRAM:IDcleanhouseID>': 30691,
#  '<BERTRAM:IDclearasmudID>': 30692,
#  '<BERTRAM:IDclearthedecksID>': 30693,
#  '<BERTRAM:IDclosebutnocigarID>': 30694,
#  '<BERTRAM:IDclosecallID>': 30695,
#  '<BERTRAM:IDcloseranksID>': 30696,
#  '<BERTRAM:IDcloseshaveID>': 30697,
#  '<BERTRAM:IDclosetohomeID>': 30698,
#  '<BERTRAM:IDclutchatstrawsID>': 30699,
#  '<BERTRAM:IDcockasnookID>': 30700,
#  '<BERTRAM:IDcockofthewalkID>': 30701,
#  '<BERTRAM:IDcoginthemachineID>': 30702,
#  '<BERTRAM:IDcoldfeetID>': 30703,
#  '<BERTRAM:IDcollectdustID>': 30704,
#  '<BERTRAM:IDcomeacropperID>': 30705,
#  '<BERTRAM:IDcomecleanID>': 30706,
#  '<BERTRAM:IDcomedownthepikeID>': 30707,
#  '<BERTRAM:IDcomefullcircleID>': 30708,
#  '<BERTRAM:IDcomehellorhighwaterID>': 30709,
#  '<BERTRAM:IDcomeinfromthecoldID>': 30710,
#  '<BERTRAM:IDcomeofageID>': 30711,
#  '<BERTRAM:IDcomeoutinthewashID>': 30712,
#  '<BERTRAM:IDcomeoutofyourshellID>': 30713,
#  '<BERTRAM:IDbananarepublicID>': 30714,
#  '<BERTRAM:IDcometoaheadID>': 30715,
#  '<BERTRAM:IDcometogriefID>': 30716,
#  '<BERTRAM:IDcometogripswithID>': 30717,
#  '<BERTRAM:IDcometomindID>': 30718,
#  '<BERTRAM:IDcometotermswithID>': 30719,
#  '<BERTRAM:IDcometothinkofitID>': 30720,
#  '<BERTRAM:IDcomeunstuckID>': 30721,
#  '<BERTRAM:IDcomeuptrumpsID>': 30722,
#  '<BERTRAM:IDconfirmedbachelorID>': 30723,
#  '<BERTRAM:IDcookthebooksID>': 30724,
#  '<BERTRAM:IDcosttheearthID>': 30725,
#  '<BERTRAM:IDcouchpotatoID>': 30726,
#  '<BERTRAM:IDcrashandburnID>': 30727,
#  '<BERTRAM:IDcrossmyheartID>': 30728,
#  '<BERTRAM:IDcrossswordsID>': 30729,
#  '<BERTRAM:IDcrosstherubiconID>': 30730,
#  '<BERTRAM:IDcruisingforabruisingID>': 30731,
#  '<BERTRAM:IDcryfoulID>': 30732,
#  '<BERTRAM:IDcrystalclearID>': 30733,
#  '<BERTRAM:IDcrywolfID>': 30734,
#  '<BERTRAM:IDcuriositykilledthecatID>': 30735,
#  '<BERTRAM:IDcutadashID>': 30736,
#  '<BERTRAM:IDcutanddriedID>': 30737,
#  '<BERTRAM:IDcutandthrustID>': 30738,
#  '<BERTRAM:IDcutarugID>': 30739,
#  '<BERTRAM:IDcutbothwaysID>': 30740,
#  '<BERTRAM:IDcutcornersID>': 30741,
#  '<BERTRAM:IDcutfromthesameclothID>': 30742,
#  '<BERTRAM:IDcutitfineID>': 30743,
#  '<BERTRAM:IDcutlooseID>': 30744,
#  '<BERTRAM:IDcutnoiceID>': 30745,
#  '<BERTRAM:IDcutthecrapID>': 30746,
#  '<BERTRAM:IDcutthemustardID>': 30747,
#  '<BERTRAM:IDcutyourlossesID>': 30748,
#  '<BERTRAM:IDblowthelidoffID>': 30749,
#  '<BERTRAM:IDdeadandburiedID>': 30750,
#  '<BERTRAM:IDdeadasadodoID>': 30751,
#  '<BERTRAM:IDdeadasadoornailID>': 30752,
#  '<BERTRAM:IDdeadinthewaterID>': 30753,
#  '<BERTRAM:IDdeadmeatID>': 30754,
#  '<BERTRAM:IDdeadtotheworldID>': 30755,
#  '<BERTRAM:IDdeadwoodID>': 30756,
#  '<BERTRAM:IDdicewithdeathID>': 30757,
#  '<BERTRAM:IDdieonthevineID>': 30758,
#  '<BERTRAM:IDdigdeepID>': 30759,
#  '<BERTRAM:IDdigupdirtID>': 30760,
#  '<BERTRAM:IDdishthedirtID>': 30761,
#  '<BERTRAM:IDdiscretionisthebetterpartofvalourID>': 30762,
#  '<BERTRAM:IDdoanumberonID>': 30763,
#  '<BERTRAM:IDdoarunnerID>': 30764,
#  '<BERTRAM:IDdogeatdogID>': 30765,
#  '<BERTRAM:IDdoginthemangerID>': 30766,
#  '<BERTRAM:IDdogtiredID>': 30767,
#  '<BERTRAM:IDdomeafavourID>': 30768,
#  '<BERTRAM:IDdonkeyworkID>': 30769,
#  '<BERTRAM:IDdoomandgloomID>': 30770,
#  '<BERTRAM:IDdothehonoursID>': 30771,
#  '<BERTRAM:IDdotherightthingID>': 30772,
#  '<BERTRAM:IDdothetrickID>': 30773,
#  '<BERTRAM:IDdownandoutID>': 30774,
#  '<BERTRAM:IDdownatheelID>': 30775,
#  '<BERTRAM:IDdowninthedumpsID>': 30776,
#  '<BERTRAM:IDdowninthemouthID>': 30777,
#  '<BERTRAM:IDdowntheroadID>': 30778,
#  '<BERTRAM:IDdownthetubesID>': 30779,
#  '<BERTRAM:IDdowntothewireID>': 30780,
#  '<BERTRAM:IDdragyourfeetID>': 30781,
#  '<BERTRAM:IDdrawabeadonID>': 30782,
#  '<BERTRAM:IDdrawablankID>': 30783,
#  '<BERTRAM:IDdrawalineinthesandID>': 30784,
#  '<BERTRAM:IDdrawstumpsID>': 30785,
#  '<BERTRAM:IDdrawtheshortstrawID>': 30786,
#  '<BERTRAM:IDdressedtokillID>': 30787,
#  '<BERTRAM:IDdressedtotheninesID>': 30788,
#  '<BERTRAM:IDdrinklikeafishID>': 30789,
#  '<BERTRAM:IDdropahintID>': 30790,
#  '<BERTRAM:IDdroplikefliesID>': 30791,
#  '<BERTRAM:IDdroptheballID>': 30792,
#  '<BERTRAM:IDdrownyoursorrowsID>': 30793,
#  '<BERTRAM:IDdrunkasalordID>': 30794,
#  '<BERTRAM:IDducksoupID>': 30795,
#  '<BERTRAM:IDdukeitoutID>': 30796,
#  '<BERTRAM:IDdutchcourageID>': 30797,
#  '<BERTRAM:IDdyedinthewoolID>': 30798,
#  '<BERTRAM:IDeasiersaidthandoneID>': 30799,
#  '<BERTRAM:IDeathumblepieID>': 30800,
#  '<BERTRAM:IDeatlikeahorseID>': 30801,
#  '<BERTRAM:IDeatyourwordsID>': 30802,
#  '<BERTRAM:IDeconomicalwiththetruthID>': 30803,
#  '<BERTRAM:IDerronthesideofID>': 30804,
#  '<BERTRAM:IDfacethemusicID>': 30805,
#  '<BERTRAM:IDeverythingbutthekitchensinkID>': 30806,
#  '<BERTRAM:IDfacetofaceID>': 30807,
#  '<BERTRAM:IDfairandsquareID>': 30808,
#  '<BERTRAM:IDfairgameID>': 30809,
#  '<BERTRAM:IDfallbythewaysideID>': 30810,
#  '<BERTRAM:IDfallfromgraceID>': 30811,
#  '<BERTRAM:IDfallinlineID>': 30812,
#  '<BERTRAM:IDfallintoplaceID>': 30813,
#  '<BERTRAM:IDfallondeafearsID>': 30814,
#  '<BERTRAM:IDfallshortID>': 30815,
#  '<BERTRAM:IDfarandawayID>': 30816,
#  '<BERTRAM:IDfastandfuriousID>': 30817,
#  '<BERTRAM:IDfeastorfamineID>': 30818,
#  '<BERTRAM:IDfeelthepinchID>': 30819,
#  '<BERTRAM:IDfewandfarbetweenID>': 30820,
#  '<BERTRAM:IDfightfirewithfireID>': 30821,
#  '<BERTRAM:IDfighttoothandnailID>': 30822,
#  '<BERTRAM:IDfillthebillID>': 30823,
#  '<BERTRAM:IDfindyourfeetID>': 30824,
#  '<BERTRAM:IDfirstamongequalsID>': 30825,
#  '<BERTRAM:IDfirstoffID>': 30826,
#  '<BERTRAM:IDfirstupID>': 30827,
#  '<BERTRAM:IDfishintroubledwatersID>': 30828,
#  '<BERTRAM:IDfitthebillID>': 30829,
#  '<BERTRAM:IDfittobetiedID>': 30830,
#  '<BERTRAM:IDflashinthepanID>': 30831,
#  '<BERTRAM:IDflatasapancakeID>': 30832,
#  '<BERTRAM:IDflyakiteID>': 30833,
#  '<BERTRAM:IDflyinthefaceofID>': 30834,
#  '<BERTRAM:IDflyoffthehandleID>': 30835,
#  '<BERTRAM:IDfoamatthemouthID>': 30836,
#  '<BERTRAM:IDfollowsuitID>': 30837,
#  '<BERTRAM:IDfollowyournoseID>': 30838,
#  '<BERTRAM:IDfootthebillID>': 30839,
#  '<BERTRAM:IDforafricaID>': 30840,
#  '<BERTRAM:IDforasongID>': 30841,
#  '<BERTRAM:IDforbiddenfruitID>': 30842,
#  '<BERTRAM:IDforgoodmeasureID>': 30843,
#  '<BERTRAM:IDforkeepsID>': 30844,
#  '<BERTRAM:IDformymoneyID>': 30845,
#  '<BERTRAM:IDforthehellofitID>': 30846,
#  '<BERTRAM:IDforthetimebeingID>': 30847,
#  '<BERTRAM:IDfreeandeasyID>': 30848,
#  '<BERTRAM:IDfreereinID>': 30849,
#  '<BERTRAM:IDfriendsinhighplacesID>': 30850,
#  '<BERTRAM:IDfromatozID>': 30851,
#  '<BERTRAM:IDfrompillartopostID>': 30852,
#  '<BERTRAM:IDfromragstorichesID>': 30853,
#  '<BERTRAM:IDfromscratchID>': 30854,
#  '<BERTRAM:IDfromstemtosternID>': 30855,
#  '<BERTRAM:IDfromthecradletothegraveID>': 30856,
#  '<BERTRAM:IDfromthewordgoID>': 30857,
#  '<BERTRAM:IDfullmarksID>': 30858,
#  '<BERTRAM:IDfullofbeansID>': 30859,
#  '<BERTRAM:IDfullspeedaheadID>': 30860,
#  '<BERTRAM:IDfulltiltID>': 30861,
#  '<BERTRAM:IDfullwhackID>': 30862,
#  '<BERTRAM:IDfunandgamesID>': 30863,
#  '<BERTRAM:IDgameonID>': 30864,
#  '<BERTRAM:IDgatherdustID>': 30865,
#  '<BERTRAM:IDgetagripID>': 30866,
#  '<BERTRAM:IDgetahandleonID>': 30867,
#  '<BERTRAM:IDgetalifeID>': 30868,
#  '<BERTRAM:IDgetamoveonID>': 30869,
#  '<BERTRAM:IDgetariseoutofID>': 30870,
#  '<BERTRAM:IDgetawaywithmurderID>': 30871,
#  '<BERTRAM:IDblowyourtopID>': 30872,
#  '<BERTRAM:IDgetdowntobrasstacksID>': 30873,
#  '<BERTRAM:IDgetinonthegroundfloorID>': 30874,
#  '<BERTRAM:IDgetitintheneckID>': 30875,
#  '<BERTRAM:IDgetitupID>': 30876,
#  '<BERTRAM:IDgetlostID>': 30877,
#  '<BERTRAM:IDgetoffthegroundID>': 30878,
#  '<BERTRAM:IDgetonlikeahouseonfireID>': 30879,
#  '<BERTRAM:IDgetthebetterofID>': 30880,
#  '<BERTRAM:IDgetthebootID>': 30881,
#  '<BERTRAM:IDgetthenodID>': 30882,
#  '<BERTRAM:IDgetthepictureID>': 30883,
#  '<BERTRAM:IDgettheshowontheroadID>': 30884,
#  '<BERTRAM:IDgettogripswithID>': 30885,
#  '<BERTRAM:IDgettothebottomofID>': 30886,
#  '<BERTRAM:IDgetwindofID>': 30887,
#  '<BERTRAM:IDgetyourfeetwetID>': 30888,
#  '<BERTRAM:IDgetyourskatesonID>': 30889,
#  '<BERTRAM:IDgetyourteethintoID>': 30890,
#  '<BERTRAM:IDgiveandtakeID>': 30891,
#  '<BERTRAM:IDgiveheadID>': 30892,
#  '<BERTRAM:IDgiveitawhirlID>': 30893,
#  '<BERTRAM:IDgiveuptheghostID>': 30894,
#  '<BERTRAM:IDgoallthewayID>': 30895,
#  '<BERTRAM:IDgoballisticID>': 30896,
#  '<BERTRAM:IDgobananasID>': 30897,
#  '<BERTRAM:IDgobeggingID>': 30898,
#  '<BERTRAM:IDgobytheboardID>': 30899,
#  '<BERTRAM:IDgodownastormID>': 30900,
#  '<BERTRAM:IDgodownhillID>': 30901,
#  '<BERTRAM:IDgodownlikealeadballoonID>': 30902,
#  '<BERTRAM:IDgodutchID>': 30903,
#  '<BERTRAM:IDgoforbrokeID>': 30904,
#  '<BERTRAM:IDgoforthejugularID>': 30905,
#  '<BERTRAM:IDgofromstrengthtostrengthID>': 30906,
#  '<BERTRAM:IDgohalvesID>': 30907,
#  '<BERTRAM:IDgohandinhandID>': 30908,
#  '<BERTRAM:IDgoitaloneID>': 30909,
#  '<BERTRAM:IDgonativeID>': 30910,
#  '<BERTRAM:IDgoodofficesID>': 30911,
#  '<BERTRAM:IDgoodriddanceID>': 30912,
#  '<BERTRAM:IDgoodsamaritanID>': 30913,
#  '<BERTRAM:IDgoofftheboilID>': 30914,
#  '<BERTRAM:IDgooverboardID>': 30915,
#  '<BERTRAM:IDgoplacesID>': 30916,
#  '<BERTRAM:IDgopublicID>': 30917,
#  '<BERTRAM:IDgoroundincirclesID>': 30918,
#  '<BERTRAM:IDgospareID>': 30919,
#  '<BERTRAM:IDgostraightID>': 30920,
#  '<BERTRAM:IDgothedistanceID>': 30921,
#  '<BERTRAM:IDgotheextramileID>': 30922,
#  '<BERTRAM:IDgothewholehogID>': 30923,
#  '<BERTRAM:IDgothroughthemotionsID>': 30924,
#  '<BERTRAM:IDgotogroundID>': 30925,
#  '<BERTRAM:IDgotoseedID>': 30926,
#  '<BERTRAM:IDgotothedogsID>': 30927,
#  '<BERTRAM:IDgotothematID>': 30928,
#  '<BERTRAM:IDgotothewallID>': 30929,
#  '<BERTRAM:IDgototownID>': 30930,
#  '<BERTRAM:IDgoupinsmokeID>': 30931,
#  '<BERTRAM:IDgowestID>': 30932,
#  '<BERTRAM:IDgowithoutsayingID>': 30933,
#  '<BERTRAM:IDgowiththeflowID>': 30934,
#  '<BERTRAM:IDgraspatstrawsID>': 30935,
#  '<BERTRAM:IDgraspthenettleID>': 30936,
#  '<BERTRAM:IDgreenlightID>': 30937,
#  '<BERTRAM:IDgrinandbearitID>': 30938,
#  '<BERTRAM:IDgrindtoahaltID>': 30939,
#  '<BERTRAM:IDgristtothemillID>': 30940,
#  '<BERTRAM:IDhackitID>': 30941,
#  '<BERTRAM:IDhairofthedogID>': 30942,
#  '<BERTRAM:IDhammerandtongsID>': 30943,
#  '<BERTRAM:IDhandingloveID>': 30944,
#  '<BERTRAM:IDhandsdownID>': 30945,
#  '<BERTRAM:IDhandtomouthID>': 30946,
#  '<BERTRAM:IDhangbyathreadID>': 30947,
#  '<BERTRAM:IDhangfireID>': 30948,
#  '<BERTRAM:IDhangtoughID>': 30949,
#  '<BERTRAM:IDhardasnailsID>': 30950,
#  '<BERTRAM:IDhardcheeseID>': 30951,
#  '<BERTRAM:IDhaveaballID>': 30952,
#  '<BERTRAM:IDhaveabashID>': 30953,
#  '<BERTRAM:IDhaveabunintheovenID>': 30954,
#  '<BERTRAM:IDhaveacowID>': 30955,
#  '<BERTRAM:IDhaveafewID>': 30956,
#  '<BERTRAM:IDhaveafootinbothcampsID>': 30957,
#  '<BERTRAM:IDhaveaheartID>': 30958,
#  '<BERTRAM:IDhaveamountaintoclimbID>': 30959,
#  '<BERTRAM:IDhaveaneyeforID>': 30960,
#  '<BERTRAM:IDhaveascrewlooseID>': 30961,
#  '<BERTRAM:IDhavebeenaroundID>': 30962,
#  '<BERTRAM:IDhaveitbothwaysID>': 30963,
#  '<BERTRAM:IDhaveiteasyID>': 30964,
#  '<BERTRAM:IDhavekittensID>': 30965,
#  '<BERTRAM:IDhavenotruckwithID>': 30966,
#  '<BERTRAM:IDhavethehotsforID>': 30967,
#  '<BERTRAM:IDhavethelastlaughID>': 30968,
#  '<BERTRAM:IDhavewordsID>': 30969,
#  '<BERTRAM:IDhaveyourworkcutoutID>': 30970,
#  '<BERTRAM:IDheadforthehillsID>': 30971,
#  '<BERTRAM:IDheadoverheelsID>': 30972,
#  '<BERTRAM:IDheadsouthID>': 30973,
#  '<BERTRAM:IDheadswillrollID>': 30974,
#  '<BERTRAM:IDheartandsoulID>': 30975,
#  '<BERTRAM:IDhearthingsID>': 30976,
#  '<BERTRAM:IDheartofgoldID>': 30977,
#  '<BERTRAM:IDhearttoheartID>': 30978,
#  '<BERTRAM:IDhighanddryID>': 30979,
#  '<BERTRAM:IDhighandlowID>': 30980,
#  '<BERTRAM:IDhighasakiteID>': 30981,
#  '<BERTRAM:IDhithomeID>': 30982,
#  '<BERTRAM:IDhitthebottleID>': 30983,
#  '<BERTRAM:IDhittheceilingID>': 30984,
#  '<BERTRAM:IDhitthegroundrunningID>': 30985,
#  '<BERTRAM:IDhitthehayID>': 30986,
#  '<BERTRAM:IDhittheheadlinesID>': 30987,
#  '<BERTRAM:IDhitthejackpotID>': 30988,
#  '<BERTRAM:IDhitthemarkID>': 30989,
#  '<BERTRAM:IDhitthenailontheheadID>': 30990,
#  '<BERTRAM:IDhittherightnoteID>': 30991,
#  '<BERTRAM:IDhittheroadID>': 30992,
#  '<BERTRAM:IDhitthesackID>': 30993,
#  '<BERTRAM:IDhittheskidsID>': 30994,
#  '<BERTRAM:IDholdalltheacesID>': 30995,
#  '<BERTRAM:IDholdcourtID>': 30996,
#  '<BERTRAM:IDholdthefortID>': 30997,
#  '<BERTRAM:IDholdthelineID>': 30998,
#  '<BERTRAM:IDholdthepursestringsID>': 30999,
#  '<BERTRAM:IDholdtheringID>': 31000,
#  '<BERTRAM:IDholdwaterID>': 31001,
#  '<BERTRAM:IDholdyourhorsesID>': 31002,
#  '<BERTRAM:IDholdyourownID>': 31003,
#  '<BERTRAM:IDholdyourtongueID>': 31004,
#  '<BERTRAM:IDhomeanddryID>': 31005,
#  '<BERTRAM:IDhopeagainsthopeID>': 31006,
#  '<BERTRAM:IDhotairID>': 31007,
#  '<BERTRAM:IDhotandbotheredID>': 31008,
#  '<BERTRAM:IDhottotrotID>': 31009,
#  '<BERTRAM:IDhotunderthecollarID>': 31010,
#  '<BERTRAM:IDinafogID>': 31011,
#  '<BERTRAM:IDinanutshellID>': 31012,
#  '<BERTRAM:IDinarutID>': 31013,
#  '<BERTRAM:IDinbedwithID>': 31014,
#  '<BERTRAM:IDinblackandwhiteID>': 31015,
#  '<BERTRAM:IDinbroaddaylightID>': 31016,
#  '<BERTRAM:IDinbusinessID>': 31017,
#  '<BERTRAM:IDincahootsID>': 31018,
#  '<BERTRAM:IDincoldbloodID>': 31019,
#  '<BERTRAM:IDindiansummerID>': 31020,
#  '<BERTRAM:IDindutchID>': 31021,
#  '<BERTRAM:IDinfullswingID>': 31022,
#  '<BERTRAM:IDinhighdudgeonID>': 31023,
#  '<BERTRAM:IDinhotwaterID>': 31024,
#  '<BERTRAM:IDinlightofID>': 31025,
#  '<BERTRAM:IDinmybookID>': 31026,
#  '<BERTRAM:IDinnouncertaintermsID>': 31027,
#  '<BERTRAM:IDinoneearandouttheotherID>': 31028,
#  '<BERTRAM:IDinspadesID>': 31029,
#  '<BERTRAM:IDinstitchesID>': 31030,
#  '<BERTRAM:IDintandemID>': 31031,
#  '<BERTRAM:IDinthebagID>': 31032,
#  '<BERTRAM:IDintheblinkofaneyeID>': 31033,
#  '<BERTRAM:IDinthebuffID>': 31034,
#  '<BERTRAM:IDinthecanID>': 31035,
#  '<BERTRAM:IDintheclearID>': 31036,
#  '<BERTRAM:IDintheclubID>': 31037,
#  '<BERTRAM:IDinthedockID>': 31038,
#  '<BERTRAM:IDinthedrivingseatID>': 31039,
#  '<BERTRAM:IDinthefinalanalysisID>': 31040,
#  '<BERTRAM:IDinthefleshID>': 31041,
#  '<BERTRAM:IDintheholeID>': 31042,
#  '<BERTRAM:IDinthelongrunID>': 31043,
#  '<BERTRAM:IDinthelongtermID>': 31044,
#  '<BERTRAM:IDintheloopID>': 31045,
#  '<BERTRAM:IDinthenickoftimeID>': 31046,
#  '<BERTRAM:IDintheoffingID>': 31047,
#  '<BERTRAM:IDinthepinkID>': 31048,
#  '<BERTRAM:IDinthepipelineID>': 31049,
#  '<BERTRAM:IDintherawID>': 31050,
#  '<BERTRAM:IDintheredID>': 31051,
#  '<BERTRAM:IDintherunningID>': 31052,
#  '<BERTRAM:IDinthesaddleID>': 31053,
#  '<BERTRAM:IDinthesamebreathID>': 31054,
#  '<BERTRAM:IDintheshortrunID>': 31055,
#  '<BERTRAM:IDinthesoupID>': 31056,
#  '<BERTRAM:IDinthesticksID>': 31057,
#  '<BERTRAM:IDintheworksID>': 31058,
#  '<BERTRAM:IDinthisdayandageID>': 31059,
#  '<BERTRAM:IDinyourbloodID>': 31060,
#  '<BERTRAM:IDinyourdreamsID>': 31061,
#  '<BERTRAM:IDinyourelementID>': 31062,
#  '<BERTRAM:IDinyourfaceID>': 31063,
#  '<BERTRAM:IDinyoursightsID>': 31064,
#  '<BERTRAM:IDitneverrainsbutitpoursID>': 31065,
#  '<BERTRAM:IDittakestwototangoID>': 31066,
#  '<BERTRAM:IDjackofalltradesID>': 31067,
#  '<BERTRAM:IDjamtomorrowID>': 31068,
#  '<BERTRAM:IDjekyllandhydeID>': 31069,
#  '<BERTRAM:IDjobsfortheboysID>': 31070,
#  '<BERTRAM:IDjockeyforpositionID>': 31071,
#  '<BERTRAM:IDjoinedatthehipID>': 31072,
#  '<BERTRAM:IDjointheclubID>': 31073,
#  '<BERTRAM:IDjumponthebandwagonID>': 31074,
#  '<BERTRAM:IDjumpshipID>': 31075,
#  '<BERTRAM:IDjumpthegunID>': 31076,
#  '<BERTRAM:IDjumpthequeueID>': 31077,
#  '<BERTRAM:IDjumpthetrackID>': 31078,
#  '<BERTRAM:IDjumpthroughhoopsID>': 31079,
#  '<BERTRAM:IDjumptoconclusionsID>': 31080,
#  '<BERTRAM:IDkeenasmustardID>': 31081,
#  '<BERTRAM:IDkeepalidonID>': 31082,
#  '<BERTRAM:IDkeepalowprofileID>': 31083,
#  '<BERTRAM:IDkeepontruckingID>': 31084,
#  '<BERTRAM:IDkeeptabsonID>': 31085,
#  '<BERTRAM:IDkeepthepeaceID>': 31086,
#  '<BERTRAM:IDkeepthewolffromthedoorID>': 31087,
#  '<BERTRAM:IDkeepupappearancesID>': 31088,
#  '<BERTRAM:IDkeepupwiththejonesesID>': 31089,
#  '<BERTRAM:IDkeepyourchinupID>': 31090,
#  '<BERTRAM:IDkeepyoureyespeeledID>': 31091,
#  '<BERTRAM:IDkeepyourfingerscrossedID>': 31092,
#  '<BERTRAM:IDkeepyourheadID>': 31093,
#  '<BERTRAM:IDkeepyournosetothegrindstoneID>': 31094,
#  '<BERTRAM:IDkeepyouroptionsopenID>': 31095,
#  '<BERTRAM:IDkickagainstthepricksID>': 31096,
#  '<BERTRAM:IDkickassID>': 31097,
#  '<BERTRAM:IDkickthebucketID>': 31098,
#  '<BERTRAM:IDkickthehabitID>': 31099,
#  '<BERTRAM:IDkickupafussID>': 31100,
#  '<BERTRAM:IDkickupastinkID>': 31101,
#  '<BERTRAM:IDkickupyourheelsID>': 31102,
#  '<BERTRAM:IDkillthegoosethatlaysthegoldeneggID>': 31103,
#  '<BERTRAM:IDkilltwobirdswithonestoneID>': 31104,
#  '<BERTRAM:IDkingofbeastsID>': 31105,
#  '<BERTRAM:IDkissandmakeupID>': 31106,
#  '<BERTRAM:IDkissandtellID>': 31107,
#  '<BERTRAM:IDkissassID>': 31108,
#  '<BERTRAM:IDkissofdeathID>': 31109,
#  '<BERTRAM:IDkissoflifeID>': 31110,
#  '<BERTRAM:IDkithandkinID>': 31111,
#  '<BERTRAM:IDknockitoffID>': 31112,
#  '<BERTRAM:IDknownoboundsID>': 31113,
#  '<BERTRAM:IDknowtheropesID>': 31114,
#  '<BERTRAM:IDknowthescoreID>': 31115,
#  '<BERTRAM:IDlameduckID>': 31116,
#  '<BERTRAM:IDlandofnodID>': 31117,
#  '<BERTRAM:IDlargerthanlifeID>': 31118,
#  '<BERTRAM:IDlasthurrahID>': 31119,
#  '<BERTRAM:IDlaughallthewaytothebankID>': 31120,
#  '<BERTRAM:IDlaughingstockID>': 31121,
#  '<BERTRAM:IDlayafingeronID>': 31122,
#  '<BERTRAM:IDlayaneggID>': 31123,
#  '<BERTRAM:IDlaydownthelawID>': 31124,
#  '<BERTRAM:IDlayeyesonID>': 31125,
#  '<BERTRAM:IDleavenostoneunturnedID>': 31126,
#  '<BERTRAM:IDleftandrightID>': 31127,
#  '<BERTRAM:IDlendahandID>': 31128,
#  '<BERTRAM:IDlendanearID>': 31129,
#  '<BERTRAM:IDletbygonesbebygonesID>': 31130,
#  '<BERTRAM:IDletsleepingdogslieID>': 31131,
#  '<BERTRAM:IDletthecatoutofthebagID>': 31132,
#  '<BERTRAM:IDletthegenieoutofthebottleID>': 31133,
#  '<BERTRAM:IDlielowID>': 31134,
#  '<BERTRAM:IDlifeandlimbID>': 31135,
#  '<BERTRAM:IDliftafingerID>': 31136,
#  '<BERTRAM:IDlightattheendofthetunnelID>': 31137,
#  '<BERTRAM:IDlikeabatoutofhellID>': 31138,
#  '<BERTRAM:IDlikeabearwithasoreheadID>': 31139,
#  '<BERTRAM:IDlikeclockworkID>': 31140,
#  '<BERTRAM:IDlikepeasinapodID>': 31141,
#  '<BERTRAM:IDliketheclappersID>': 31142,
#  '<BERTRAM:IDlivealieID>': 31143,
#  '<BERTRAM:IDliveandletliveID>': 31144,
#  '<BERTRAM:IDliveinsinID>': 31145,
#  '<BERTRAM:IDliveitupID>': 31146,
#  '<BERTRAM:IDlivewireID>': 31147,
#  '<BERTRAM:IDlockhornsID>': 31148,
#  '<BERTRAM:IDlonewolfID>': 31149,
#  '<BERTRAM:IDlonginthetoothID>': 31150,
#  '<BERTRAM:IDlongtimenoseeID>': 31151,
#  '<BERTRAM:IDlookbeforeyouleapID>': 31152,
#  '<BERTRAM:IDlookonthebrightsideID>': 31153,
#  '<BERTRAM:IDlooktheotherwayID>': 31154,
#  '<BERTRAM:IDlookthepartID>': 31155,
#  '<BERTRAM:IDlosefaceID>': 31156,
#  '<BERTRAM:IDloseheartID>': 31157,
#  '<BERTRAM:IDlosetheplotID>': 31158,
#  '<BERTRAM:IDloseyourheadID>': 31159,
#  '<BERTRAM:IDloseyourshirtID>': 31160,
#  '<BERTRAM:IDmakeacleanbreakID>': 31161,
#  '<BERTRAM:IDmakeagoofID>': 31162,
#  '<BERTRAM:IDmakeakillingID>': 31163,
#  '<BERTRAM:IDmakeamealofID>': 31164,
#  '<BERTRAM:IDmakeamountainoutofamolehillID>': 31165,
#  '<BERTRAM:IDmakeamoveID>': 31166,
#  '<BERTRAM:IDmakeanightofitID>': 31167,
#  '<BERTRAM:IDmakeapitchID>': 31168,
#  '<BERTRAM:IDmakeasplashID>': 31169,
#  '<BERTRAM:IDmakeendsmeetID>': 31170,
#  '<BERTRAM:IDmakehayID>': 31171,
#  '<BERTRAM:IDmakeheadortailofID>': 31172,
#  '<BERTRAM:IDmakehistoryID>': 31173,
#  '<BERTRAM:IDmakelightofID>': 31174,
#  '<BERTRAM:IDmakeorbreakID>': 31175,
#  '<BERTRAM:IDmakeshortworkofID>': 31176,
#  '<BERTRAM:IDmakethecutID>': 31177,
#  '<BERTRAM:IDmakethegradeID>': 31178,
#  '<BERTRAM:IDmaketracksID>': 31179,
#  '<BERTRAM:IDmakewavesID>': 31180,
#  '<BERTRAM:IDmakeyourbloodboilID>': 31181,
#  '<BERTRAM:IDmanandboyID>': 31182,
#  '<BERTRAM:IDmanofgodID>': 31183,
#  '<BERTRAM:IDmarchingordersID>': 31184,
#  '<BERTRAM:IDmeatandpotatoesID>': 31185,
#  '<BERTRAM:IDmeetyourmakerID>': 31186,
#  '<BERTRAM:IDmeetyourmatchID>': 31187,
#  '<BERTRAM:IDmendfencesID>': 31188,
#  '<BERTRAM:IDmisstheboatID>': 31189,
#  '<BERTRAM:IDmomentoftruthID>': 31190,
#  '<BERTRAM:IDmoneyforjamID>': 31191,
#  '<BERTRAM:IDmoneytalksID>': 31192,
#  '<BERTRAM:IDmoveheavenandearthID>': 31193,
#  '<BERTRAM:IDmovemountainsID>': 31194,
#  '<BERTRAM:IDmovethegoalpostsID>': 31195,
#  '<BERTRAM:IDmuchofamuchnessID>': 31196,
#  '<BERTRAM:IDmuddythewatersID>': 31197,
#  '<BERTRAM:IDmybadID>': 31198,
#  '<BERTRAM:IDnamenamesID>': 31199,
#  '<BERTRAM:IDneartheknuckleID>': 31200,
#  '<BERTRAM:IDneckandneckID>': 31201,
#  '<BERTRAM:IDneckofthewoodsID>': 31202,
#  '<BERTRAM:IDneitherfishnorfowlID>': 31203,
#  '<BERTRAM:IDneitherherenorthereID>': 31204,
#  '<BERTRAM:IDneversaydieID>': 31205,
#  '<BERTRAM:IDneverthetwainshallmeetID>': 31206,
#  '<BERTRAM:IDneveryoumindID>': 31207,
#  '<BERTRAM:IDnewbloodID>': 31208,
#  '<BERTRAM:IDniceaspieID>': 31209,
#  '<BERTRAM:IDnightanddayID>': 31210,
#  '<BERTRAM:IDninetimesoutoftenID>': 31211,
#  '<BERTRAM:IDnipandtuckID>': 31212,
#  '<BERTRAM:IDnocandoID>': 31213,
#  '<BERTRAM:IDnodiceID>': 31214,
#  '<BERTRAM:IDnogreatshakesID>': 31215,
#  '<BERTRAM:IDnolaughingmatterID>': 31216,
#  '<BERTRAM:IDnorestforthewickedID>': 31217,
#  '<BERTRAM:IDnospringchickenID>': 31218,
#  '<BERTRAM:IDnosweatID>': 31219,
#  '<BERTRAM:IDnotallthereID>': 31220,
#  '<BERTRAM:IDnotbataneyeID>': 31221,
#  '<BERTRAM:IDnotcricketID>': 31222,
#  '<BERTRAM:IDnotgiveafigID>': 31223,
#  '<BERTRAM:IDnothingdoingID>': 31224,
#  '<BERTRAM:IDnothingtoitID>': 31225,
#  '<BERTRAM:IDnothingtowritehomeaboutID>': 31226,
#  '<BERTRAM:IDnotimelikethepresentID>': 31227,
#  '<BERTRAM:IDnotonyourlifeID>': 31228,
#  '<BERTRAM:IDnottobesneezedatID>': 31229,
#  '<BERTRAM:IDnottoputtoofineapointonitID>': 31230,
#  '<BERTRAM:IDnotwowaysaboutitID>': 31231,
#  '<BERTRAM:IDnoworneverID>': 31232,
#  '<BERTRAM:IDnudgenudgewinkwinkID>': 31233,
#  '<BERTRAM:IDoddoneoutID>': 31234,
#  '<BERTRAM:IDoffandonID>': 31235,
#  '<BERTRAM:IDoffthecuffID>': 31236,
#  '<BERTRAM:IDoffthehookID>': 31237,
#  '<BERTRAM:IDoffthemarkID>': 31238,
#  '<BERTRAM:IDofftherecordID>': 31239,
#  '<BERTRAM:IDofftheshelfID>': 31240,
#  '<BERTRAM:IDoffthetopofyourheadID>': 31241,
#  '<BERTRAM:IDoffthewallID>': 31242,
#  '<BERTRAM:IDoilandwaterID>': 31243,
#  '<BERTRAM:IDoldasthehillsID>': 31244,
#  '<BERTRAM:IDoldhatID>': 31245,
#  '<BERTRAM:IDonafullstomachID>': 31246,
#  '<BERTRAM:IDonandoffID>': 31247,
#  '<BERTRAM:IDonarollID>': 31248,
#  '<BERTRAM:IDonashoestringID>': 31249,
#  '<BERTRAM:IDonasilverplatterID>': 31250,
#  '<BERTRAM:IDonboardID>': 31251,
#  '<BERTRAM:IDonceandforallID>': 31252,
#  '<BERTRAM:IDonceinabluemoonID>': 31253,
#  '<BERTRAM:IDonceinawhileID>': 31254,
#  '<BERTRAM:IDoncloudnineID>': 31255,
#  '<BERTRAM:IDoneandthesameID>': 31256,
#  '<BERTRAM:IDonedgeID>': 31257,
#  '<BERTRAM:IDonefortheroadID>': 31258,
#  '<BERTRAM:IDonegoodturndeservesanotherID>': 31259,
#  '<BERTRAM:IDoneofthosedaysID>': 31260,
#  '<BERTRAM:IDoneofthosethingsID>': 31261,
#  '<BERTRAM:IDoniceID>': 31262,
#  '<BERTRAM:IDonpaperID>': 31263,
#  '<BERTRAM:IDontenterhooksID>': 31264,
#  '<BERTRAM:IDonthebackburnerID>': 31265,
#  '<BERTRAM:IDonthebackofID>': 31266,
#  '<BERTRAM:IDontheballID>': 31267,
#  '<BERTRAM:IDonthebounceID>': 31268,
#  '<BERTRAM:IDonthebuttonID>': 31269,
#  '<BERTRAM:IDonthecardsID>': 31270,
#  '<BERTRAM:IDonthecarpetID>': 31271,
#  '<BERTRAM:IDonthecuffID>': 31272,
#  '<BERTRAM:IDonthedotID>': 31273,
#  '<BERTRAM:IDonthedoubleID>': 31274,
#  '<BERTRAM:IDonthefaceofitID>': 31275,
#  '<BERTRAM:IDonthefiddleID>': 31276,
#  '<BERTRAM:IDontheflyID>': 31277,
#  '<BERTRAM:IDonthegameID>': 31278,
#  '<BERTRAM:IDonthehoofID>': 31279,
#  '<BERTRAM:IDonthehopID>': 31280,
#  '<BERTRAM:IDonthehornID>': 31281,
#  '<BERTRAM:IDonthehornsofadilemmaID>': 31282,
#  '<BERTRAM:IDonthehouseID>': 31283,
#  '<BERTRAM:IDonthelamID>': 31284,
#  '<BERTRAM:IDonthelevelID>': 31285,
#  '<BERTRAM:IDonthemendID>': 31286,
#  '<BERTRAM:IDbowandscrapeID>': 31287,
#  '<BERTRAM:IDboxcleverID>': 31288,
#  '<BERTRAM:IDonthenoseID>': 31289,
#  '<BERTRAM:IDonthepullID>': 31290,
#  '<BERTRAM:IDonthereboundID>': 31291,
#  '<BERTRAM:IDontherocksID>': 31292,
#  '<BERTRAM:IDontheropesID>': 31293,
#  '<BERTRAM:IDontherunID>': 31294,
#  '<BERTRAM:IDonthesamepageID>': 31295,
#  '<BERTRAM:IDonthesamewavelengthID>': 31296,
#  '<BERTRAM:IDontheshelfID>': 31297,
#  '<BERTRAM:IDonthesideoftheangelsID>': 31298,
#  '<BERTRAM:IDontheskidsID>': 31299,
#  '<BERTRAM:IDonthespurofthemomentID>': 31300,
#  '<BERTRAM:IDonthesquareID>': 31301,
#  '<BERTRAM:IDonthestumpID>': 31302,
#  '<BERTRAM:IDonthetakeID>': 31303,
#  '<BERTRAM:IDonthetrotID>': 31304,
#  '<BERTRAM:IDontheupandupID>': 31305,
#  '<BERTRAM:IDonthewagonID>': 31306,
#  '<BERTRAM:IDonthewarpathID>': 31307,
#  '<BERTRAM:IDonthiniceID>': 31308,
#  '<BERTRAM:IDontopoftheworldID>': 31309,
#  '<BERTRAM:IDonyoursoapboxID>': 31310,
#  '<BERTRAM:IDonyourtoesID>': 31311,
#  '<BERTRAM:IDopenthefloodgatesID>': 31312,
#  '<BERTRAM:IDoutandaboutID>': 31313,
#  '<BERTRAM:IDoutcoldID>': 31314,
#  '<BERTRAM:IDoutofkilterID>': 31315,
#  '<BERTRAM:IDoutoflineID>': 31316,
#  '<BERTRAM:IDoutoforderID>': 31317,
#  '<BERTRAM:IDoutofpocketID>': 31318,
#  '<BERTRAM:IDoutofsightID>': 31319,
#  '<BERTRAM:IDoutofsortsID>': 31320,
#  '<BERTRAM:IDoutoftheboxID>': 31321,
#  '<BERTRAM:IDoutoftheloopID>': 31322,
#  '<BERTRAM:IDoutofthepictureID>': 31323,
#  '<BERTRAM:IDoutofthequestionID>': 31324,
#  '<BERTRAM:IDoutoftherunningID>': 31325,
#  '<BERTRAM:IDoutofthewoodsID>': 31326,
#  '<BERTRAM:IDoutofthinairID>': 31327,
#  '<BERTRAM:IDoutofwhackID>': 31328,
#  '<BERTRAM:IDoutofyourmindID>': 31329,
#  '<BERTRAM:IDoutonalimbID>': 31330,
#  '<BERTRAM:IDouttolunchID>': 31331,
#  '<BERTRAM:IDoverthecounterID>': 31332,
#  '<BERTRAM:IDoverthehillID>': 31333,
#  '<BERTRAM:IDoverthemoonID>': 31334,
#  '<BERTRAM:IDoverthetopID>': 31335,
#  '<BERTRAM:IDoveryourheadID>': 31336,
#  '<BERTRAM:IDpackapunchID>': 31337,
#  '<BERTRAM:IDpaintthetownredID>': 31338,
#  '<BERTRAM:IDpaperoverthecracksID>': 31339,
#  '<BERTRAM:IDboysinblueID>': 31340,
#  '<BERTRAM:IDcastyourmindbackID>': 31341,
#  '<BERTRAM:IDpassmusterID>': 31342,
#  '<BERTRAM:IDpassthebuckID>': 31343,
#  '<BERTRAM:IDpassthetimeofdayID>': 31344,
#  '<BERTRAM:IDpaythepiperID>': 31345,
#  '<BERTRAM:IDpaythroughthenoseID>': 31346,
#  '<BERTRAM:IDpeachesandcreamID>': 31347,
#  '<BERTRAM:IDpeckingorderID>': 31348,
#  '<BERTRAM:IDperishthethoughtID>': 31349,
#  '<BERTRAM:IDpickholesID>': 31350,
#  '<BERTRAM:IDpickupthepiecesID>': 31351,
#  '<BERTRAM:IDpickupthetabID>': 31352,
#  '<BERTRAM:IDpieintheskyID>': 31353,
#  '<BERTRAM:IDpissandvinegarID>': 31354,
#  '<BERTRAM:IDpissedoffID>': 31355,
#  '<BERTRAM:IDplaceinthesunID>': 31356,
#  '<BERTRAM:IDplainasapikestaffID>': 31357,
#  '<BERTRAM:IDplainjaneID>': 31358,
#  '<BERTRAM:IDplainsailingID>': 31359,
#  '<BERTRAM:IDplanbID>': 31360,
#  '<BERTRAM:IDplayballID>': 31361,
#  '<BERTRAM:IDplayfastandlooseID>': 31362,
#  '<BERTRAM:IDplayfortimeID>': 31363,
#  '<BERTRAM:IDplaygamesID>': 31364,
#  '<BERTRAM:IDplayhardtogetID>': 31365,
#  '<BERTRAM:IDplayitcoolID>': 31366,
#  '<BERTRAM:IDplayitsafeID>': 31367,
#  '<BERTRAM:IDplaypossumID>': 31368,
#  '<BERTRAM:IDplaythefieldID>': 31369,
#  '<BERTRAM:IDplaywithfireID>': 31370,
#  '<BERTRAM:IDpleasedaspunchID>': 31371,
#  '<BERTRAM:IDpointthefingerID>': 31372,
#  '<BERTRAM:IDpoorasachurchmouseID>': 31373,
#  '<BERTRAM:IDpoorlittlerichgirlID>': 31374,
#  '<BERTRAM:IDpopthequestionID>': 31375,
#  '<BERTRAM:IDpoundthepavementID>': 31376,
#  '<BERTRAM:IDpourcoldwateronID>': 31377,
#  '<BERTRAM:IDpowerbehindthethroneID>': 31378,
#  '<BERTRAM:IDpractisewhatyoupreachID>': 31379,
#  '<BERTRAM:IDpresenceofmindID>': 31380,
#  '<BERTRAM:IDpressthefleshID>': 31381,
#  '<BERTRAM:IDpressthepanicbuttonID>': 31382,
#  '<BERTRAM:IDprickupyourearsID>': 31383,
#  '<BERTRAM:IDprodigalsonID>': 31384,
#  '<BERTRAM:IDpropupthebarID>': 31385,
#  '<BERTRAM:IDpullafaceID>': 31386,
#  '<BERTRAM:IDpullafastoneID>': 31387,
#  '<BERTRAM:IDpullarabbitoutofahatID>': 31388,
#  '<BERTRAM:IDpulloutallthestopsID>': 31389,
#  '<BERTRAM:IDpullrankID>': 31390,
#  '<BERTRAM:IDpullstringsID>': 31391,
#  '<BERTRAM:IDpulltheplugID>': 31392,
#  '<BERTRAM:IDcatchacoldID>': 31393,
#  '<BERTRAM:IDcountsheepID>': 31394,
#  '<BERTRAM:IDpumpironID>': 31395,
#  '<BERTRAM:IDpureandsimpleID>': 31396,
#  '<BERTRAM:IDpushingupthedaisiesID>': 31397,
#  '<BERTRAM:IDpushtheboatoutID>': 31398,
#  '<BERTRAM:IDpushtheenvelopeID>': 31399,
#  '<BERTRAM:IDpushthepanicbuttonID>': 31400,
#  '<BERTRAM:IDputadamperonID>': 31401,
#  '<BERTRAM:IDputafootwrongID>': 31402,
#  '<BERTRAM:IDputasockinitID>': 31403,
#  '<BERTRAM:IDputdownrootsID>': 31404,
#  '<BERTRAM:IDputpaidtoID>': 31405,
#  '<BERTRAM:IDputthebootinID>': 31406,
#  '<BERTRAM:IDputthecartbeforethehorseID>': 31407,
#  '<BERTRAM:IDputthecatamongthepigeonsID>': 31408,
#  '<BERTRAM:IDputthekiboshonID>': 31409,
#  '<BERTRAM:IDputthemovesonID>': 31410,
#  '<BERTRAM:IDputthescrewsonID>': 31411,
#  '<BERTRAM:IDputthewindupID>': 31412,
#  '<BERTRAM:IDputuporshutupID>': 31413,
#  '<BERTRAM:IDputyourbestfootforwardID>': 31414,
#  '<BERTRAM:IDputyourfootdownID>': 31415,
#  '<BERTRAM:IDputyourfootinitID>': 31416,
#  '<BERTRAM:IDquickasaflashID>': 31417,
#  '<BERTRAM:IDquietasamouseID>': 31418,
#  '<BERTRAM:IDraincatsanddogsID>': 31419,
#  '<BERTRAM:IDrainorshineID>': 31420,
#  '<BERTRAM:IDraisecainID>': 31421,
#  '<BERTRAM:IDraisehellID>': 31422,
#  '<BERTRAM:IDraisetheroofID>': 31423,
#  '<BERTRAM:IDrankandfileID>': 31424,
#  '<BERTRAM:IDreachforthestarsID>': 31425,
#  '<BERTRAM:IDreadbetweenthelinesID>': 31426,
#  '<BERTRAM:IDreadmylipsID>': 31427,
#  '<BERTRAM:IDredsunderthebedID>': 31428,
#  '<BERTRAM:IDreinventthewheelID>': 31429,
#  '<BERTRAM:IDrestonyourlaurelsID>': 31430,
#  '<BERTRAM:IDrhymeorreasonID>': 31431,
#  '<BERTRAM:IDrideherdonID>': 31432,
#  '<BERTRAM:IDridehighID>': 31433,
#  '<BERTRAM:IDrideroughshodoverID>': 31434,
#  '<BERTRAM:IDrideshotgunID>': 31435,
#  '<BERTRAM:IDridetherailsID>': 31436,
#  '<BERTRAM:IDrightasrainID>': 31437,
#  '<BERTRAM:IDrightupyourstreetID>': 31438,
#  '<BERTRAM:IDringabellID>': 31439,
#  '<BERTRAM:IDriseandshineID>': 31440,
#  '<BERTRAM:IDrisefromtheashesID>': 31441,
#  '<BERTRAM:IDrisethroughtheranksID>': 31442,
#  '<BERTRAM:IDrisetotheoccasionID>': 31443,
#  '<BERTRAM:IDrobpetertopaypaulID>': 31444,
#  '<BERTRAM:IDrockbottomID>': 31445,
#  '<BERTRAM:IDcountyourblessingsID>': 31446,
#  '<BERTRAM:IDdownthedrainID>': 31447,
#  '<BERTRAM:IDrollwiththepunchesID>': 31448,
#  '<BERTRAM:IDroughandtumbleID>': 31449,
#  '<BERTRAM:IDrougharoundtheedgesID>': 31450,
#  '<BERTRAM:IDroughedgesID>': 31451,
#  '<BERTRAM:IDroundthebendID>': 31452,
#  '<BERTRAM:IDroundtheclockID>': 31453,
#  '<BERTRAM:IDrubshouldersID>': 31454,
#  '<BERTRAM:IDrubsomeoneupthewrongwayID>': 31455,
#  '<BERTRAM:IDruleofthumbID>': 31456,
#  '<BERTRAM:IDruletheroostID>': 31457,
#  '<BERTRAM:IDrunamileID>': 31458,
#  '<BERTRAM:IDrunamokID>': 31459,
#  '<BERTRAM:IDrunbeforeyoucanwalkID>': 31460,
#  '<BERTRAM:IDrunintothesandID>': 31461,
#  '<BERTRAM:IDrunoutofgasID>': 31462,
#  '<BERTRAM:IDrunoutofsteamID>': 31463,
#  '<BERTRAM:IDrunriotID>': 31464,
#  '<BERTRAM:IDrunthegamutID>': 31465,
#  '<BERTRAM:IDrunthegauntletID>': 31466,
#  '<BERTRAM:IDsadsackID>': 31467,
#  '<BERTRAM:IDsafeashousesID>': 31468,
#  '<BERTRAM:IDsamedifferenceID>': 31469,
#  '<BERTRAM:IDsavedbythebellID>': 31470,
#  '<BERTRAM:IDsavefaceID>': 31471,
#  '<BERTRAM:IDsavethedayID>': 31472,
#  '<BERTRAM:IDsaycheeseID>': 31473,
#  '<BERTRAM:IDsayuncleID>': 31474,
#  '<BERTRAM:IDscarletwomanID>': 31475,
#  '<BERTRAM:IDscratchthesurfaceID>': 31476,
#  '<BERTRAM:IDscreambluemurderID>': 31477,
#  '<BERTRAM:IDsecondchildhoodID>': 31478,
#  '<BERTRAM:IDsecondnatureID>': 31479,
#  '<BERTRAM:IDseeeyetoeyeID>': 31480,
#  '<BERTRAM:IDseenbetterdaysID>': 31481,
#  '<BERTRAM:IDseeredID>': 31482,
#  '<BERTRAM:IDseestarsID>': 31483,
#  '<BERTRAM:IDseetheelephantID>': 31484,
#  '<BERTRAM:IDseethelightID>': 31485,
#  '<BERTRAM:IDseethelightofdayID>': 31486,
#  '<BERTRAM:IDseizethedayID>': 31487,
#  '<BERTRAM:IDselllikehotcakesID>': 31488,
#  '<BERTRAM:IDsellyoursoulID>': 31489,
#  '<BERTRAM:IDseparatethewheatfromthechaffID>': 31490,
#  '<BERTRAM:IDseteyesonID>': 31491,
#  '<BERTRAM:IDsetthewheelsinmotionID>': 31492,
#  '<BERTRAM:IDsettleascoreID>': 31493,
#  '<BERTRAM:IDsetyoursightsonID>': 31494,
#  '<BERTRAM:IDshakealegID>': 31495,
#  '<BERTRAM:IDshipshapeandbristolfashionID>': 31496,
#  '<BERTRAM:IDshootfromthehipID>': 31497,
#  '<BERTRAM:IDdownthehatchID>': 31498,
#  '<BERTRAM:IDfitasafiddleID>': 31499,
#  '<BERTRAM:IDshootthemessengerID>': 31500,
#  '<BERTRAM:IDshortshriftID>': 31501,
#  '<BERTRAM:IDshowalegID>': 31502,
#  '<BERTRAM:IDshowtheflagID>': 31503,
#  '<BERTRAM:IDshrinkingvioletID>': 31504,
#  '<BERTRAM:IDshuffleoffthismortalcoilID>': 31505,
#  '<BERTRAM:IDshutthedooronID>': 31506,
#  '<BERTRAM:IDsickandtiredID>': 31507,
#  '<BERTRAM:IDsickasadogID>': 31508,
#  '<BERTRAM:IDsicktodeathID>': 31509,
#  '<BERTRAM:IDsignofthetimesID>': 31510,
#  '<BERTRAM:IDsilenceisgoldenID>': 31511,
#  '<BERTRAM:IDsingthepraisesofID>': 31512,
#  '<BERTRAM:IDsinkorswimID>': 31513,
#  '<BERTRAM:IDsitonthefenceID>': 31514,
#  '<BERTRAM:IDsittightID>': 31515,
#  '<BERTRAM:IDsittingduckID>': 31516,
#  '<BERTRAM:IDsixfeetunderID>': 31517,
#  '<BERTRAM:IDslaponthewristID>': 31518,
#  '<BERTRAM:IDsleeplikealogID>': 31519,
#  '<BERTRAM:IDsleeproughID>': 31520,
#  '<BERTRAM:IDsleightofhandID>': 31521,
#  ...}

# %%
# Test for MWE single-tokens
test_tokens = ['<BERTRAM:IDoffthebeatentrackID>', '<BERTRAM:IDchapterandverseID>', '<BERTRAM:IDjointheclubID>', '<BERTRAM:IDtietheknotID>']

# %%
for token in test_tokens:
    assert tokenizer.tokenize(f'This is a {token}')[-1] == token, f"Error:{token} not detected"
    print(tokenizer.tokenize(f'This is a {token}'))

print(f'SUCCESS!! The {SeqClassification_model_path} tokenizer model has been tested!!')
# Out:
# ['this', 'is', 'a', '<BERTRAM:IDoffthebeatentrackID>']
# ['this', 'is', 'a', '<BERTRAM:IDchapterandverseID>']
# ['this', 'is', 'a', '<BERTRAM:IDjointheclubID>']
# ['this', 'is', 'a', '<BERTRAM:IDtietheknotID>']
# SUCCESS!! The ../local_models/bert-base-uncased_option1_with_bertram_bt2_SC tokenizer model has been tested!!

# %%
# TEST THE SequenceClassification model
def get_model_predictions(sents):
    inputs=tokenizer(sents, padding=True, truncation=True, return_tensors="pt")
    outputs = model(**inputs) 
    logits = outputs.logits
    print(logits)
    predictions = torch.argmax(logits, dim=-1)
    return predictions

sents = [f'This {token} is very very bad', f'This is a {token} with very long sentence!']
for token in test_tokens:
    for sent in sents:
        preds = get_model_predictions([sent])
        print(f"Input token:{token} \nPredictions:{preds}")
        print('-'*30)
# Out:
# tensor([[-0.0267, -0.2155]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDoffthebeatentrackID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0011, -0.0722]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDoffthebeatentrackID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0267, -0.2155]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDchapterandverseID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0011, -0.0722]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDchapterandverseID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0267, -0.2155]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDjointheclubID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0011, -0.0722]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDjointheclubID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0267, -0.2155]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDtietheknotID>
# Predictions:tensor([0])
# ------------------------------
# tensor([[-0.0011, -0.0722]], grad_fn=<AddmmBackward0>)
# Input token:<BERTRAM:IDtietheknotID>
# Predictions:tensor([0])
# ------------------------------
